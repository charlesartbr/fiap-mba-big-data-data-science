# %%
# importing required libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# target URL to scrap
url = "https://www.goibibo.com/hotels/hotels-in-shimla-ct/"

# %%
# headers
headers = {
 'User-Agent': "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.90 Safari/537.36"
}

# %%
# send request to download the data
response = requests.request("GET", url, headers=headers)

# %%
# parse the downloaded data
data = BeautifulSoup(response.text, 'html.parser')
print(data)
# Out:
# <!DOCTYPE html>
# <html lang="en-US"><head><title>Hotels in Shimla - Book 832 Shimla Hotels with 𝘂𝗽𝘁𝗼 𝟱𝟬% off @ ₹275</title><meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width, initial-scale=1.0" name="viewport"/><meta content="Best Shimla Hotels with upto 50% off from Goibibo. Check 57647 reviews and 38902 photos for 832  Shimla Hotels. Use coupon code GETSETGO and grab best deals starting from  @ ₹275 on Shimla online hotel booking. ✔ Lowest Price Guarantee ✔ Fastest Booking ✔ Instant Refund" name="description"/><meta content="width=device-width,initial-scale=1.0, maximum-scale=5.0, user-scalable=0" name="viewport"/><meta content="hotels in Shimla, best hotels in Shimla, Shimla hotels, Shimla hotel booking, Shimla hotel price, Shimla hotel deals, book Shimla hotels, goibibo Shimla hotels" name="keywords"/><link href="//www.goibibo.com/images/favicon.ico" rel="shortcut icon" type="image/ico"/><meta content="Hotels in Shimla -  Book 832  Shimla Hotels with 𝘂𝗽𝘁𝗼 𝟱𝟬% off  @ ₹275" property="og:title"/><meta content="Best Shimla Hotels with upto 50% off from Goibibo. Check 57647 reviews and 38902 photos for 832  Shimla Hotels. Use coupon code GETSETGO and grab best deals starting from  @ ₹275 on Shimla online hotel booking. ✔ Lowest Price Guarantee ✔ Fastest Booking ✔ Instant Refund" property="og:description"/><meta content="https://cdn1.goibibo.com/himachal-pradesh-shimla-147617005104o.jpg" property="og:image"/><meta content="https://www.goibibo.com/hotels/hotels-in-shimla-ct/" property="og:url"/><link href="https://www.goibibo.com/hotels/hotels-in-shimla-ct/" rel="canonical"/><link href="https://www.goibibo.com/hotels/hotels-in-shimla-ct/?pg=2" rel="next"/><link href='android-app://com.goibibo/goibibo/www.goibibo.com/app/hotels/hotels-in-shimla-ct/?params={"go_data": {"n": "shimla", "oid": "1449073512565742573", "t": "area", "cid": "1449073512565742573"}, "tag_id": 202}' rel="alternate"/><link as="style" href="https://fonts.googleapis.com/css?family=Quicksand&amp;display=swap" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/></head><body class="width100 fl"><noscript><meta content="0;url='https://www.goibibo.com/hotels/hotels-in-shimla-ct/?PageSpeed=noscript'" http-equiv="refresh"/><style><!--table,div,span,font,p{display:none} --></style><div style="display:block">Please click <a href="https://www.goibibo.com/hotels/hotels-in-shimla-ct/?PageSpeed=noscript">here</a> if you are not redirected within a few seconds.</div></noscript><div class="bgdiv" id="new-hotel-loading-div" style="position: fixed; font-family: 'Quicksand', sans-serif !important; display:none"><div id="background-loader-text" onclick="event.stopPropagation()" style="border-radius: 30px; margin: 150px auto; background-color: white; width: 643px; height: 336px;"><div style="width: 100%; height: 213px;"><script pagespeed_no_defer="">//<![CDATA[
# (function(){var g=encodeURIComponent,h=window,k=document,l="width",m="documentElement",n="height",p="length",q=this,r=function(b,d){var a=b.split("."),c=q;a[0]in c||!c.execScript||c.execScript("var "+a[0]);for(var e;a[p]&&(e=a.shift());)a[p]||void 0===d?c[e]?c=c[e]:c=c[e]={}:c[e]=d};var t=function(b){var d=b[p];if(0<d){for(var a=Array(d),c=0;c<d;c++)a[c]=b[c];return a}return[]};var u=function(b){var d=h;if(d.addEventListener)d.addEventListener("load",b,!1);else if(d.attachEvent)d.attachEvent("onload",b);else{var a=d.onload;d.onload=function(){b.call(this);a&&a.call(this)}}};var v,w=function(b,d,a,c,e){this.f=b;this.h=d;this.i=a;this.c=e;this.e={height:h.innerHeight||k[m].clientHeight||k.body.clientHeight,width:h.innerWidth||k[m].clientWidth||k.body.clientWidth};this.g=c;this.b={};this.a=[];this.d={}},x=function(b,d){var a,c,e=d.getAttribute("pagespeed_url_hash");if(a=e)if(a=!(e in b.d))if(0>=d.offsetWidth&&0>=d.offsetHeight)a=!1;else{c=d.getBoundingClientRect();var f=k.body;a=c.top+("pageYOffset"in h?h.pageYOffset:(k[m]||f.parentNode||f).scrollTop);c=c.left+("pageXOffset"in
# h?h.pageXOffset:(k[m]||f.parentNode||f).scrollLeft);f=a.toString()+","+c;b.b.hasOwnProperty(f)?a=!1:(b.b[f]=!0,a=a<=b.e[n]&&c<=b.e[l])}a&&(b.a.push(e),b.d[e]=!0)};w.prototype.checkImageForCriticality=function(b){b.getBoundingClientRect&&x(this,b)};r("pagespeed.CriticalImages.checkImageForCriticality",function(b){v.checkImageForCriticality(b)});r("pagespeed.CriticalImages.checkCriticalImages",function(){y(v)});
# var y=function(b){b.b={};for(var d=["IMG","INPUT"],a=[],c=0;c<d[p];++c)a=a.concat(t(k.getElementsByTagName(d[c])));if(0!=a[p]&&a[0].getBoundingClientRect){for(c=0;d=a[c];++c)x(b,d);a="oh="+b.i;b.c&&(a+="&n="+b.c);if(d=0!=b.a[p])for(a+="&ci="+g(b.a[0]),c=1;c<b.a[p];++c){var e=","+g(b.a[c]);131072>=a[p]+e[p]&&(a+=e)}b.g&&(e="&rd="+g(JSON.stringify(z())),131072>=a[p]+e[p]&&(a+=e),d=!0);A=a;if(d){c=b.f;b=b.h;var f;if(h.XMLHttpRequest)f=new XMLHttpRequest;else if(h.ActiveXObject)try{f=new ActiveXObject("Msxml2.XMLHTTP")}catch(s){try{f=
# new ActiveXObject("Microsoft.XMLHTTP")}catch(B){}}f&&(f.open("POST",c+(-1==c.indexOf("?")?"?":"&")+"url="+g(b)),f.setRequestHeader("Content-Type","application/x-www-form-urlencoded"),f.send(a))}}},z=function(){var b={},d=k.getElementsByTagName("IMG");if(0==d[p])return{};var a=d[0];if(!("naturalWidth"in a&&"naturalHeight"in a))return{};for(var c=0;a=d[c];++c){var e=a.getAttribute("pagespeed_url_hash");e&&(!(e in b)&&0<a[l]&&0<a[n]&&0<a.naturalWidth&&0<a.naturalHeight||e in b&&a[l]>=b[a.src].k&&a[n]>=
# b[a.src].j)&&(b[e]={rw:a[l],rh:a[n],ow:a.naturalWidth,oh:a.naturalHeight})}return b},A="";r("pagespeed.CriticalImages.getBeaconData",function(){return A});r("pagespeed.CriticalImages.Run",function(b,d,a,c,e,f){var s=new w(b,d,a,e,f);v=s;c&&u(function(){h.setTimeout(function(){y(s)},0)})});})();
#
# pagespeed.CriticalImages.Run('/mod_pagespeed_beacon','https://www.goibibo.com/hotels/hotels-in-shimla-ct/','9h69CgP56i',true,false,'oDjuPkSmap8');
# //]]></script><img alt="Loading Screen" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="2129554552" src="https://gos3.ibcdn.com/screen-loader-1568375554.png" style="width: auto; height: 175px; margin: 25px auto;"/></div><p style="width: 393px; margin: 0px auto; font-size: 22px; font-weight: bold; color: #2276e3;">LOADING THE BEST PRICES FOR YOU</p><div style="font-weight: normal; color: #898b91;"><p>We get you the best prices, everytime. Serving over 600k</p><p>customers worldwide everyday</p></div></div></div><div itemscope="" itemtype="http://schema.org/WebPage"><div id="app-install-widget"></div><script src="//goibibo.ibcdn.com/hotelsnew/static/js/lib/jquery.2.1.3.min.1483561221.js"></script><script src="//goibibo.ibcdn.com/styleguide/js/respond.min.1483563658.js"></script><script src="//goibibo.ibcdn.com/js/v2/headerV2.1568333090.js"></script><script src="//goibibo.ibcdn.com/js/v2/header_common.1568333090.js"></script><div class="headerBox col-md-12 col-sm-12 col-xs-12"><div class="hdrLeft"><a class="hdrLogo" href="/"><img onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="753931433" src="//goibibo.ibcdn.com/styleguide/images/goLogo.png"/></a><ul class="mainLinks"><li class="active"><a href="/flights/"><i class="icon-flights db blue ico24 lh1-2 padT5 padB5"></i> <span class="iconText">Flights</span></a></li><li class=""><a href="/hotels/"><i class="icon-hotels db blue ico28 lh1-2 padT2 padB3"></i> <span class="iconText">Hotels</span></a></li><li class=""><a href="/gostays/"><i class="icon-gostays icon-gostays-cstm db blue padT5 padB5"></i> <span class="iconText">Hotels</span></a></li><li class=""><a href="/bus/"><i class="icon-bus db blue ico24 lh1-2 padT5 padB5"></i> <span class="iconText">Bus</span></a></li><li class="posRel"><a href="/trains/"><img alt="irctc train logo" class="marginT5 marginB5" height="25px" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="3286845901" src="/styleguide/images/train_logo.png" width="24px"/><span class="iconText">IRCTC Trains</span></a></li><li class="posRel"><a href="/cars/"><i class="icon-airport-transfer db blue ico24 lh1-2 padT5 padB5"></i><span class="iconText">Cabs</span></a></li><li class="hdrMoreLink"><div class="padB10 lh1-2 iconText fmtTooltip">more +<div class="tip tip_top white moreSubLinks"><a href="/international-flights/"><i class="icon-flights padR10 blue ico20 fl"></i> <span class="fl padT3">International Flights</span></a><a href="/mobile/"><i class="icon-mobiles padR10 blue ico20 fl"></i> <span class="fl padT3">Mobile Apps</span></a> <a href="/destinations/"><i class="icon-destination padR10 blue ico20 fl"></i> <span class="fl padT3">Destinations</span></a> <a href="/ask/"><i class="icon-ask padR10 blue ico20 fl"></i> <span class="fl padT3">Ask</span></a> <a href="/routeplanner/"><i class="icon-route-planner padR10 blue ico20 fl"></i> <span class="fl padT3">Route Planner</span></a> <a href="/offers/"><i class="icon-offer-badge padR10 blue ico20 fl"></i> <span class="fl padT3">Offers &amp; Promotions</span></a> <a href="/info/reviews-and-rating/"><i class="icon-photo-review padR10 blue ico22 fl"></i> <span class="fl padT3">Reviews &amp; Ratings</span></a> <a href="/trains/check-train-running-status/"><i class="icon-train-front-view padR10 blue ico22 fl"></i> <span class="fl padT3">Train Runing Status</span></a> <a href="/trains/check-pnr-status/"><i class="icon-train-front-view padR10 blue ico22 fl"></i> <span class="fl padT3">Check PNR Status</span></a></div></div></li></ul></div><div class="hdrRight"><div class="width100 fl txtRight padB5 padR5"><a class="hdrCusSupport vMid padR15" href="/support/"><small class="fl ico13 lh1-2">24x7 goCare Support</small></a> <span class="vMid dib txtRight hdrUserName" id="hdr_user_signin"><span class="ico13 blue db"><a href="javascript:void(0)" onclick="window.location.href = '/accounts/login/?next=' + location.href;  ">Sign  ...
#     $(window).on('load',function(){
#
#         if(widget && widget.autosuggestSetter)
#         {
#             widget.autosuggestSetter({"title": "Shimla", "country": "IN", "entityType": "city", "cityName": "Shimla", "cityId": "1449073512565742573", "entityId": "1449073512565742573"});
#         }
#
#
#
#
#     });
#
# </script><div class="searchWrapOuterBox bgBlue row"><div class="searchInnerBox"><a class="dn ipaddn mobdb button orange large fl width100 marginB10 goCamp" href="javascript:void(0)" id="searchHotelButton" style="display:none !important;">Search<span class="goKarde"></span></a><form class="mobSearchToggle1" id="gi_search_hp" method="post" name="gi_search" onsubmit="return false;"><div class="col-md-12 col-sm-12 col-xs-12 pad0"><div class="col-lg-5 col-md-4 col-sm-12 col-xs-12 autoSuggestBox"><input autocomplete="off" class="form-control txtInput" id="gosuggest_inputL" placeholder="Enter City name, Area name or Hotel name" type="text"/><div class="col-md-12 col-sm-12 col-xs-12 autoWrap marginTM10"></div></div><div class="col-lg-3 col-md-3 col-sm-5 col-xs-12"><div class="fl width100 calenderOuterBox"><div class="col-md-6 col-xs-6 calenderInnerBox" id="ciHolder"><a class="width100 fl" data-date="" href="javascript:void(0)" id="start-date_hp"><i class="icon-calendar1 black ico26 fl padR5"></i> <span class="fl font13Dr padT5" id="ci_srp_day">Checkin</span></a><div class="jrdp_calendar_pos" id="start-calen_hp"></div></div><div class="col-md-6 col-xs-6 calenderInnerBox last" id="coHolder"><a class="width100 fl" data-date="" href="javascript:void(0)" id="end-date_hp"><i class="icon-calendar1 black ico26 fl padR5"></i> <span class="fl font13Dr padT5" id="co_srp_day">Checkout</span></a><div class="jrdp_calendar_pos" id="end-calen_hp"></div></div></div></div><div class="col-lg-2 col-md-3 col-sm-4 col-xs-12"><div class="paxWrapper"><a class="paxBox" href="javascript:void(0);" id="pax_link_hp"><i class="icon-user greyLt ico18 fl marginT2 padR5"></i> <span class="ico13 black padT5 fl" id="home_textHook">1 Guests / 1 Rooms</span> <i class="icon-arrow-down txtgrey ico18 padT5 fr"></i></a><div class="width100 fl paxWrapCont borderAll dn" id="paxcontainer_home"><div id="summaryContainer"></div><div id="editBox"></div><div class="width100 fl borderBtm marginB10 bg-greyLtest1" id="addButton"></div></div></div></div><div class="col-lg-2 col-md-2 col-sm-3 col-xs-12 marginB10 goCamp"><button class="button orange large ipadButtonSpace width100" id="hm_srch" type="submit">Search<span class="goKarde"></span></button></div></div></form></div></div><div class="dn" id="template-placeholder"></div><script id="go_suggestions" type="text/template">
# 		<ul class="autoSuggestBoxList flt dn">
# 			<% _.each(list, function(item,count) { %>
# 				<li <% if(item.left.cityHead){ %> class="cityhead" <%}%> <% if(item.left.indent){ %>class="indent" <%}%> data-index="<%= count %>">
# 					<% if(item.left.cityHead){ %>
# 						<% if(item.meta.pageType == 'offers'){%>
# 							<div class="fl padR2 hidden-sm hidden-xs padT5">
# 						<i class="fl icon-city ico11"></i>
# 						<% } else { %>
# 							<div class="fl padR2 hidden-sm hidden-xs padR2 padT5">
# 							<i class="fl icon-city ico14"></i>
# 						<% } %>
# 						</div> <%}%>
# 						<% if(item.meta.context=='flights'){%>
# 							<% if (item.left.cityHead == false){ %>
# 								<% if(item.meta.pageType == 'offers'){%>
# 									<div class="fl hidden-sm  padT5 hidden-xs">
# 								<i class="fl icon-flights ico12"></i>
# 								<% } else { %>
# 									<div class="fl padT5 hidden-sm padR10 hidden-xs">
#  									<i class="fl icon-flights ico14"></i>
# 								<% } %>
#
# 							</div><%}%>
# 							<% if(item.meta.suggestType == 'multi'){%> <div class="dib marginL10 col-md-10 col-sm-12 col-xs-12 pad0 textOverflow"><% } %>
# 							<% if(item.meta.pageType == 'offers'){%> <div class="dib marginL10 col-md-10 col-sm-12 col-xs-12 pad0 textOverflow"> <% } else { %><div class="dib col-md-11 col-sm-12 col-xs-12 pad0 textOverflow"><% } %>
# 								<div class="mainTxt clearfix">
# 									<span> <%= item.left.mainTxt %> </span> <span class="txtTransUpper ico14 greyLt">(<%= item.right.span %>)</span>
# 								</div>
# 								<% if(item.meta.suggestType == 'multi'){%>
# 									<div class="fl auto-ctryMult-ellip auto-ctryAir-ellip padT2">
# 								<% } else { %>
#  									<div class="fl auto-ctryAir-ellip mobEllipsis padT2">
# 								<% } %>
# 										<span class="clearfix">
# 											<small class="font12Lt"> <%= item.left.subTxtSpan %></small>
# 										</span>
#
# 									</div>
# 								<span class="fr">
# 									<% if(item.meta.pageType == 'offers'){%>
# 										<small class="font12Lt vMid padR5 dib"><%= item.left.subTextCName %></small>
# 									<% } else { %>
# 										<small class="font12Lt vMid padR5 dib"><%= item.left.subTxtSmall %></small>
# 									<% } %>
# 									<span class="flag-sprt vMid dib <%= item.left.subTextCName.toLowerCase() %>"></span>
# 								</span>
# 								<span class="clearfix">&nbsp;</span>
#
# 								<% if(item.left.dis && item.left.cityNameDis) {%>
# 										<span class="clearfix">
# 											<small class="font12Lt"> <span class="fb">(<%= Math.floor(item.left.dis) %></span> KMs from <span class="fb"><%= item.left.cityNameDis %></span>)</small>
# 										</span>
# 									<% } %>
# 							</div>
# 						<% } else { %>
# 							<div class="dib col-md-8 col-sm-8 pad0 <%if(item.meta.context){ %> col-xs-8 <% }else{ %>col-xs-12<% } %> <%if(item.meta.context=='flights'){ %> textOverflow <% } %>">
# 								<div class="mainTxt">
# 									<span><%= item.left.mainTxt %></span><% if(item.left.subTxtSpan){ %>
# 										<span class=""> &ndash; <%= item.left.subTxtSpan %></span>
# 										<% }else if(item.left.subTxtSmall){ %>
# 											<small class="font11Lt"><%= item.left.subTxtSmall %></small>
# 										<% } %>
# 								</div>
# 							</div>
# 						<% } %>
# 						<% if(item.meta.context!='flights'){%>
# 							<div class="col-md-4 col-sm-4 pad0 <%if(item.meta.context){ %> col-xs-4 <% }else{ %>col-xs-12<% } %>">
# 								<div class="fr width100">
# 									<% if(item.right.rating){%>
# 										<div class="fl">
# 											<div class="autoGoRating fl">
# 												<i class="icon-reverse-go ico15 orange fl"></i>
# 												<small class="fl padL5 padT2"><b><%= item.right.rating%></b>
# 													<span class="font11Lt">/5</span>
# 												</small>
# 											</div>
# 											<% if(item.right.reviewCount){ %>
# 												<small class="autoReviewers  padT2 fl width100">
# 													<span><%=item.right.reviewCount%></span> <span>Reviews</span>
# 												</small>
# 											<% } %>
# 										</div>
# 									<% } %>
#
# 									<% if(item.right.span){%>
# 									<% } else if(item.right.group){%>
# 										<% if(item.right.group.span){%>
# 											<span class="statusTag auto txtLeft"><%=item.right.group.span%></span>
# 										<% } %>
# 										<i class="ht_bgAutoSuggest ht_<%= item.right.group.type %> fr"></i>
# 										<small class="margin5 dib pad3 fr"><%= item.right.group.type %></small>
# 									<% } %>
# 								</div>
# 							</div>
# 						<% } %>
# 					</li>
# 				<% }); %>
# 			</ul>
# 		</script><script id="go_suggestions_error" type="text/template">
# 			<ul class="autoSuggestBoxList dn">
# 				<li> No matching result found.</li>
# 			</ul>
# 		</script><script id="pax_select" type="text/template">
#     <div class="widgetUserBlock fl <%=val.containerClass%>">
#         <label class="ico13 db padB5"><span><%=val.label%></span><small class="font10Lt db padT3"> <%=val.subLabel%></small></label>
#         <div class="customSelect">
#             <select <%if(val.react){ %> class="hasChild" id="<%=val.id%>" <% } %> name="<%=val.label.replace(' ','')%>">
#             <% for(var i=val.min;i<=val.max;i++){ %>
#             <option value="<%=i%>" <%if(val.value==i){ %>selected<% } %>><%=i%></option>
#             <% } %>
#             </select>
#         </div>
#     </div>
# </script><script id="pax_li" type="text/template">
#     <li class="roomRow">
#         <% if(config.boxHeading.visible){ %>
#         <h4 class="padTB5"><%=config.boxHeading.label%>
#             <% if(config.boxHeading.useIndex){ %>
#             <%=++config.boxHeading.index%>
#             <% } %>
#         </h4>
#         <%}%>
#         <% _.each(entity, function(person,key){ %>
#         <% if(person.visible){ %>
#         <%=renderSelect({val:person})%>
#         <%if(person.childConfig){ %>
#         <%for(var z=1;z<=person.value;z++){ %>
#         <%=renderSelect({val:person.childConfig[z-1]})%>
#         <%};%>
#         <%}%>
#         <%}%>
#         <% }); %>
#     </li>
# </script><script id="pax_template" type="text/template">
#     <div class="paxMobile dn paxContainer">
#         <a class="icon-cancel-circle fr marginT10 marginR10 fr greyDr mobdn" id="pax_close" href="javascript:void(0);"></a>
#         <ul>
#             <% _.each(config.entities, function(entity,idx){ %>
#             <%=renderLi({config:config,entity:entity,renderSelect:renderSelect})%>
#             <% }); %>
#
#             <% if(config.actionLinks.visible){ %>
#             <li class="fl txtCenter">
#                 <a class="fl ico16 pad15" href="javascript:void(0)" id="add">Add <%=config.actionLinks.textToAppend%></a>
#                 <a class="fl ico16 pad15 dn" href="javascript:void(0)" id="remove">Remove <%=config.actionLinks.textToAppend%></a>
#             </li>
#             <% }%>
#         </ul>
#     </div>
# </script><script id="summaryTemplate" type="text/template">
#
# 	<%for(var i=0; i<roomObject.roomconfig.length; i++){%>
#
# 		<div class="width100 fl posRel borderBtm summary" data-serial="<%=i+1%>">
#
# 			<div class="rowIcons nClick">
# 				<a class="icon-edit fl greyLt ico16 pad5 nClick" href="javascript:void(0);"></a>
# 				<%if(roomObject.roomconfig.length != 1){%>
# 					<a class="icon-close1 fl pad5 red nClick" href="javascript:void(0);" data-close="true"></a>
# 				<% } %>
# 			</div>
# 			<div class="userselected fl width100 nClick">
# 				<span class="fl ico14 pad10 grey lh1-2 bg-greyLtest1 fb nClick">Room <%=i+1%></span>
# 				<span class="fl pad10 tipLeft nClick"><%=roomObject.roomconfig[i].adult%> <%=roomObject.roomconfig[i].adultTag%> / <%=roomObject.roomconfig[i].children%> <%=roomObject.roomconfig[i].childTag%></span>
# 			</div>
#
# 		</div>
#
# 	<% } %>
#
# </script><script id="editTemplate" type="text/template">
#
# 		<div class="width100 fl posRel borderBtm">
# 			<div class="rowIcons">
# 				<a class="icon-close1 fl pad5 red nClick" href="javascript:void(0);" id="editClose"></a>
# 			</div>
# 			<div class="useredit fl width100 pad10" id="edtHook" data-mode= "<%=mode%>" data-serial = "<%=rmnumber + 1%>">
# 				<h4 class="padTB5 ico14 grey lh1-2">Room <%=rmnumber + 1%></h4>
# 				<div class="widgetUserBlock fl " ele="adult">
# 			        <label class="ico13 db padB5"><span>Adult</span><small class="font10Lt db padT3"> (12+ yrs)</small></label>
# 			        <div class="customSelect">
# 			            <select name="Adult">
# 			            <%for(var x=1; x<5; x++ ){%>
# 			            	<option value="<%=x%>"
# 			            		<% if(x == adult) { %>
# 			            			selected="selected"
# 					            <% } %>
# 					         ><%=x%></option>
# 					     <% } %>
# 			            </select>
# 			        </div>
# 			    </div>
# 				<div class="widgetUserBlock fl " ele="children">
# 			        <label class="ico13 db padB5"><span>Children</span><small class="font10Lt db padT3"> (2-12 yrs)</small></label>
# 			        <div class="customSelect">
# 			            <select class="hasChild" id="children" name="children">
# 			            	<%for(var x=0; x<3; x++ ){%>
# 				            	<option value="<%=x%>"
# 				            		<% if(x == children) { %>
# 				            			selected="selected"
# 						            <% } %>
# 						         ><%=x%></option>
# 						     <% } %>
# 			            </select>
# 			        </div>
# 			    </div>
# 			    <div class="widgetUserBlock fl children <% if(!age1){ %> dn <% } %>" id="childBox1" ele="age1">
# 					<label class="ico13 db padB5"><span>Child 1</span><small class="font10Lt db padT3"> Select age</small></label>
# 			        <div class="customSelect">
# 			            <select name="Child1">
#
# 			            	<%for(var x=1; x<13; x++ ){%>
# 				            	<option value="<%=x%>"
# 				            		<% if(x == age1) { %>
# 				            			selected="selected"
# 						            <% } %>
# 						         ><%=x%></option>
# 						     <% } %>
#
# 			            </select>
# 			        </div>
# 			    </div>
# 			    <div class="widgetUserBlock fl children <% if(!age2){ %> dn <% } %>" id="childBox2" ele="age2">
# 					<label class="ico13 db padB5"><span>Child 2</span><small class="font10Lt db padT3"> Select age</small></label>
# 			        <div class="customSelect">
# 			            <select name="Child2">
#
# 				            <%for(var x=1; x<13; x++ ){%>
# 				            	<option value="<%=x%>"
# 				            		<% if(x == age2) { %>
# 				            			selected="selected"
# 						            <% } %>
# 						         ><%=x%></option>
# 						     <% } %>
#
# 			            </select>
# 			        </div>
# 			    </div>
# 		    </div>
# 	    </div>
#
# </script><script id="addTemplate" type="text/template">
#
# 	<%if(roomObject.roomconfig.length < 6){%>
# 		<a class="button outlineBlue fl margin5 txtTransUpper nClick" id="addRoom">+ Add Room</a>
# 	<% } else {%>
# 		<div class="width100 fl pad10 txtCenter borderBtm">
# 			<span class="width100 fl grey ico12 lh1-2">Need more rooms? Contact our travel expert on</span>
# 			<span class="width100 dib padT2 ico13">
# 				<span class="dib blue">1800 267 9999</span>
# 				<span class="dib grey padL4 padR4">or</span>
# 				<span class="dib blue">
# 					<a href="mailto:holidays@goibibo.com">holidays@goibibo.com</a>
# 				</span>
# 			</span>
# 		</div>
# 	<% } %>
# 	<button class="button blue fr margin5 xsmall nClick" id="editSubmit">Done</button>
#
# </script><script>
# 		proto = window.location.protocol;
# 	</script><script src="//goibibo.ibcdn.com/hotelsnew/static/js/widget_hotels-lib-min.1483561221.js" type="text/javascript"></script></div> <div class="clear"></div><div class="width100 fl greyBg"><div class="seoPageHtl marginAuto"><div class="breadcrumb marginTB5 lh1-5 col-md-9 col-sm-9 col-xs-12 padL15" style="margin-bottom: -5px;"><div class="fl" itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb"><a href="/" itemprop="url" title="Home"><span itemprop="title">Goibibo</span></a>→ </div><div class="fl" itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb"><a href="/hotels/" itemprop="url" title="Hotel Booking"><span itemprop="title">Hotel Booking</span></a>→ </div><div class="fl" itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb"><a href="/hotels/india/" itemprop="url" title="Hotels in India"><span itemprop="title">India</span></a> → </div><div class="fl"><span>Shimla</span></div></div></div></div><div class="clear"></div><div class="width100 fl greyBg"><div class="seoPageHtl marginAuto"><div class="col-md-12 col-sm-12 col-xs-12 padLR10"><div class="width100 fl"><a class="posRel button showFiltr orange xsmall fr ipaddb mobdn dn" onclick="">Hide Filter</a><section class="col-md-9 col-sm-12 col-xs-12 fr wid80 pad0" style="width: 75% !important;"><div id="price-loader"><div class="price-loader-text">Fetching best deals for you<div class="typing_loader"></div></div></div><div style="clear: both;"></div><div class="col-md-12 col-sm-12 col-xs-12 marginB10 marginT10 dn" id="search-head1"><div class="fl font15">Current Search Filters</div><div id="current-search-btns"></div></div><div class="dn" id="add-more-loc-head"><div class="txt-cap fl marginL20" id="add-more-loc"><a class="filter-btn txt-cap" onclick="HotelCityApp.searchEvents.focusLocationFilter()" style="background-color: #f26722;" title="Add More Locations">+ Add More</a></div></div><div class="dn fl marginL5 width100 marginT5" id="sort-div"><div class="sort-tab sort-tab-active" id="popularity" onclick="HotelCityApp.searchEvents.processSort('popularity')" title="Sort by popularity">Popularity</div><div class="sort-tab" id="price-low" onclick="HotelCityApp.searchEvents.processSort('price-low')" title="Sort by price low to high">Price Low To High</div><div class="sort-tab" id="price-high" onclick="HotelCityApp.searchEvents.processSort('price-high')" title="Sort by price high to low">Price High To Low</div><div class="col-md-3 col-sm-3 col-xs-12"><select class="listdropdown locDropDown dn" id="sort-type" onchange="HotelCityApp.searchEvents.multiLocationSort()"></select></div></div><div style="clear:both;"></div><div class="width100 fl padB5" id="outerSrpLocContainer" style="margin-top:10px;padding-left:5px; padding-right:5px;"><div class="searchBlk posRel" id="srpLocContainer" style="background: rgb(255, 255, 255); border-width: 0px 1px 1px; border-top-style: initial; border-right-style: solid; border-bottom-style: solid; border-left-style: solid; border-top-color: initial; border-right-color: rgb(230, 230, 230); border-bottom-color: rgb(230, 230, 230); border-left-color: rgb(230, 230, 230); border-image: initial;"><span class="fl ico16 black padT4 marginTB5" style="width: 260px;"><i class="icon-area ico18 fl marginR5 borderBtm redDr padR4"></i>Find By Location or Address</span><div class="fl posRel" style="width:500px;"><div class="fl padL20 autoSuggestBox" style="width:100%;"><div class="fl marginTB5 posRel" id="location-search-div" style="width:100%;"></div></div></div><span class="offerTag"><span class="dib">New</span></span></div></div><div style="clear:both;"></div><div style="clear:both;"></div><div class="width100 fl pad5 padding-top-0" id="main-page-div" style="padding-top: 0px;margin-top:-18px;"><div style="width: 100%; float: left; margin-top: 10px; margin-bottom: 10px;"><div class="col-md-12 col-sm-12 col-xs-12 marginT10" id="all-hotels-container"><div class="col-md-9 col-sm-12 col-xs-12"><i class="fl icon-hotels blue ico28"></i><h1 class ...
# <div id="htl-<%= hotel_data.id %>" class="width100 fl htlListSeo hotel-tile-srp-container hotel-tile-srp-container-template"  onclick="window.open('<%= hotel_data.url %>'); event.stopPropagation();">
#     <div class="hotel-tile-srp-container-img-container">
#         <% if (hotel_data.bkfstOverlay && hotel_data.bkfstOverlay === 1) {%>
#             <div class="htl-tile-free-bkfst-overlay" style="display: block;">
#                 <div class="text-label">Free breakfast</div>
#                 <div class="label-decor"></div>
#             </div>
#         <% } %>
#         <div class="hotel-tile-srp-container-title-image">
#             <img class="lazy" src="<%= hotel_data.img %>" ori="<%= hotel_data.img %>" id="htl-tile-main-image-<%= hotel_data.id %>" alt="<%= hotel_data.name %> - <%= hotel_data.location %>">
#         </div>
#         <% if (hotel_data.img_gallery.length > 1) {%>
#             <ul class="hotel-tile-srp-container-image-gallery">
#                 <% for (var idx in hotel_data.img_gallery) {%>
#                     <li>
#                         <% if ((hotel_data.img_gallery.length-idx) === 1) {%>
#                             <div style="cursor:pointer !important;">
#                                 VIEW ALL
#                             </div>
#                         <% } %>
#                         <img src="<%=hotel_data.img_gallery[idx].th%>" fsi="<%=hotel_data.img_gallery[idx].fs%>" alt="Images for Hotel" class="lazy htl-tile-gallery-image" htl="<%= hotel_data.id %>" onmouseenter="onImageHover(this, 'in')" onmouseleave="onImageHover(this, 'out')">
#                     </li>
#                 <% } %>
#             </ul>
#         <% } %>
#     </div>
#     <div class="hotel-tile-srp-container-content-container">
# 		<ul class="hotel-content-container-top-hinged-list">
# 			<li>
# 				<div style="display: inline-block; float:left;">
#                     <% for (var i=0; i<hotel_data.star_rating; i++) {%>
# 					    <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i>
#                     <% } %>
# 					<span style="padding: 2px; border: 1px solid #e5edf6; border-radius: 2px; margin-left: 5px; color: #4f525a">HOTEL</span>
# 				</div>
#                 <div>
#                  <% if  (hotel_data.ugc_src == "ta" && hotel_data.ta_rating != "") { %>
#                          <div style="background-color: green; height: 20px; -webkit-border-radius:5px; float:right; margin-left:8px;">
#                              <span >
#                              <img src="https://gos3.ibcdn.com/trip_adviser-1557838494.png" alt="Trip Advisor Logo" style="max-width: 25.5px; max-height: 12px; margin: 5px 0px 5px 5px;">
#                              <span class="ico16" style="color:#ffffff;  margin: 4px 7px 3px 5px; font-size:12px; float:right;">
#                                  <strong> <%= hotel_data.ta_rating %> </strong> /5 </span>
#                              </span>
#                          </div>
#                     <% } %>
#                 </div>
# 				<div style="float: right; margin-top:3px;">
#                     <% if (hotel_data.review_count) {%>
#                         <span><%= hotel_data.review_count %> reviews</span>
#                     <% } %>
#                     <% if (hotel_data.ugc_src === "gir" && hotel_block_config.go_rating === true && hotel_data.go_rating != "" && hotel_data.go_rating > 0) {%>
#                         <span style="padding: 4px; background-color: <% if (hotel_data.go_rating >= 4.0){ %>#7ccf50<% } else if (hotel_data.go_rating >= 3.0 ){ %>#afd600<% } else { %>#fdaf15<% } %>; color: white; border-radius: 2px; margin-left: 5px;"><%= hotel_data.go_rating %>/5</span>
#                     <% } %>
#                     <% if (!(hotel_data.review_count || (hotel_data.ugc_src === "gir" && hotel_block_config.go_rating === true && hotel_data.go_rating != "" && hotel_data.go_rating > 0) || (hotel_data.ugc_src === "ta" && hotel_block_config.ta_rating === true && hotel_data.ta_rating != "" && hotel_data.ta_rating > 0))) {%>
#                     <span>New Listing</span>
#                     <span style="padding: 4px 6px;background-color: #1aabb8;color: white;border-radius: 2px;">NEW</span>
#                     <% } %>
#                 </div>
# 			</li>
# 			<li>
#                 <a href="<%= hotel_data.url %>" target="_blank" onclick="event.stopPropagation();"><p style="font-size: 18px; font-weight: bolder; color: #141823;font-family: 'Quicksand', sans-serif;  margin-top:17px;"><%= hotel_data.name %></p></a>
#             </li>
# 			<% if (hotel_data.location) {%>
#             <li style="color: #2276e3;">
#                 <p><%= hotel_data.location %></p>
#             </li>
#             <% } %>
# 		</ul>
# 		<ul class="hotel-content-container-bottom-hinged-list">
# 			<li>
# 				<i class="icon-ranking" style="font-size: 15px; margin-right: 3px; color: #fdba00"></i>
#                 <% if (hotel_data.topTag && hotel_data.topTag != '') {%>
#                     <span class="htl-tile-top-tag-text" style="color: #2276e3; cursor: pointer"><%= hotel_data.topTag %></span>
#                 <% } else if (hotel_data.reco_percent && hotel_data.reco_percent != '0') {%>
#                     <span class="htl-tile-top-tag-text" style="color: #2276e3; cursor: pointer"><%= hotel_data.reco_percent %>% Guests recommend this hotel</span>
#                 <% } else { %>
#                     <span class="htl-tile-top-tag-text" style="color: #2276e3; cursor: pointer"></span>
#                 <% } %>
# 			</li>
#             <% if (hotel_data.locPin && hotel_data.locPin != "") {%>
#                 <li class="hotel-content-container-li-loc-usp" style="display: block;">
#                     <i class="icon-persuation-generic" style="font-size: 15px; margin-right: 3px;"></i>
#                     <span class="htl-tile-loc-pin-text"><%= hotel_data.locPin %></span>
#                 </li>
#             <% } %>
#             <% if (hotel_data.htl_amen_list) {%>
#                 <li style="" class="htl-tile-amenities-list">
#                     <% if (hotel_data.htl_amen_list.room_service === true) {%>
#                         <div style="">
#                             <i class="icon-service2" style=""></i>
#                             <span>Room Service</span>
#                         </div>
#                     <% } %>
#                     <% if (hotel_data.htl_amen_list.internet === true) {%>
#                         <div style="">
#                             <i class="icon-wifi-free" style=""></i>
#                             <span>Free Internet</span>
#                         </div>
#                     <% } %>
#                     <% if (hotel_data.htl_amen_list.restaurant === true) {%>
#                         <div style="">
#                             <i class="icon-restaurant2" style=""></i>
#                             <span>Restaurant/Coffee Shop</span>
#                         </div>
#                     <% } %>
#                     <% if (hotel_data.htl_amen_list.swimming_pool === true) {%>
#                         <div style="">
#                             <i class="icon-swimming2" style=""></i>
#                             <span>Swimming Pool</span>
#                         </div>
#                     <% } %>
#                 <% if (hotel_data.htl_rem_amen_cnt > 0) {%>
#                     <span style="color: #2276e3; cursor: pointer">+ <%= hotel_data.htl_rem_amen_cnt %> More</span>
#                 <% } %>
#                 </li>
#             <% } %>
#
# 			<% if (hotel_data.couple_friendly && hotel_data.couple_friendly === 1) {%>
#                 <li style="color: #ff3a5c;">
#                     <i class="icon-couple-man-woman" style="font-size: 15px; margin-right: 3px;"></i>
#                     <span>Couple Friendly</span>
#                 </li>
#             <% } %>
#             <% if (hotel_data.stlDeal && hotel_data.stlDeal != "") {%>
# 			<li style="color: #861388;">
# 				<span>
# 					<i class="icon-steal-deal" style="font-size: 15px; margin-right: 3px;"></i>
# 					<!--<i class="icon-path" style="font-size: 15px; margin-right: 3px;"></i>-->
# 				</span>
# 				<span style="padding: 3px 8px; border-radius: 10px; background-color: #f2e7f3;">Steal Deal</span>
#                 <span style="margin-left: 5px; color: black;" class="htl-tile-steal-deal-text"><%= hotel_data.stlDeal %></span>
# 			</li>
#             <% } %>
# 			<!--<li style="border-radius: 4px; background-color: #eef4fd; margin-top: 4px;">
# 				 <span style="background-image: linear-gradient(285deg, #cf125d, #ff3478); color: white; padding: 2px 8px; border-radius: 2px; margin-right: 5px;">
#                     GIFT CARD
#                 </span>
#                 <span>1500 TAJ Experiences card for use at any Taj</span>
#                 <span style="display: inline-block; margin-left: 5px; color: #2276e3;">+More</span>
# 			</li>
# 			<li style="border-radius: 4px;background-color: #eef4fd;">
# 				<span style="background-image: linear-gradient(107deg, #1149f3, #00c3ff); color: white; padding: 2px 8px; border-radius: 2px; margin-right: 5px;">SPL DEAL</span>
#                 <span>Free 30min SPA session</span>
#                 <span style="display: inline-block; margin-left: 5px; color: #2276e3;">+More</span>
# 			</li>-->
# 		</ul>
# 	</div>
# 		<div style="width: 200px; margin: 12px 10px 0px 6px; display: inline-block; border-left: 1px solid #e5edf6; height: 256px; position: absolute; right: 0px; font-size: 12px; color: #4f525a;">
#             <% if (hotel_data.bannerText && hotel_data.bannerText != "") {%>
#                 <div style="font-size: 12px; font-weight: bold; position: absolute; top: -24px; right: 10px;">
#                     <div style="display: inline-block; width: 0px; height: 0px; border-right: 5px solid #898b91; border-left: 5px solid transparent; border-top: 5px solid transparent; border-bottom: 5px solid #898b91; margin: -9px 0px 0px 0px;"></div>
#                     <div class="htl-tile-banner-text-div" style="margin: 0px -4px; display: inline-block; padding: 1px 10px; background-image: linear-gradient(284deg, #adaeb2, #34393a); color: white; width: max-content; border-bottom-right-radius: 2px; border-bottom-left-radius: 2px; height: 17px;">
#                         <%= hotel_data.bannerText %>
#                     </div>
#                     <div style="display: inline-block; width: 0px; height: 0px; border-right: 5px solid transparent; border-left: 5px solid #898b91; border-top: 5px solid transparent; border-bottom: 5px solid #898b91; margin: -9px 0px 0px 0px;"></div>
#                 </div>
#             <% } %>
#             <% if (hotel_data.fcpText && hotel_data.fcpText != "") {%>
#                 <div style="background-color: aliceblue; width: 182px; text-align: center; border-radius: 10px; margin: 5px auto;">
#                     <span style="color: #2bac36;" class="htl-tile-fcp-text"><%= hotel_data.fcpText %></span>
#                 </div>
#             <% } %>
# 			<div style="text-align: right; position: absolute; top: 75px; right: 0px;">
#                 <ul>
#                     <li style="height: 27px; display: none" class="htl-tile-prc-loader">
#                         <div class="typing_loader" style="float: unset;"></div>
#                     </li>
#                     <% if (hotel_data.so) { %>
#                     <li style="font-size: 18px;color: black;font-weight: bold;" class="htl-tile-sold-out-label">SOLD OUT</li>
#                     <% } else { %>
#                         <% if (hotel_data.oprc) { %>
#                             <li style="text-decoration: line-through;" class="htl-tile-non-discount-prc">
#                                 <i class="icon-rupee rupee-icon" style="font-size: 12px;"></i><%= hotel_data.oprc %>
#                             </li>
#                         <% } %>
#                         <% if (hotel_block_config.price == true && hotel_data.booking_price != "" && hotel_data.booking_price > 0) {%>
#                         <li style="font-size: 22px; color: black; font-weight: bold;" class="htl-tile-discount-prc">
#                             <i class="icon-rupee rupee-icon" style="font-size: 16px;"></i><%= hotel_data.booking_price %>
#                         </li>
#                         <li>per room/night</li>
#                         <% } %>
#                     <% } %>
#                     <% if (hotel_data.offersCount && hotel_data.offersCount > 0) {%>
#                         <li style="background-color: #fef8e5; color: #8e5a14;">
#                             <i class="icon-gocash-plus" style="font-size: 15px; color: #fdba00;"></i>
#                             <span style="margin: 5px;" class="htl-tile-offers-count">+<%= hotel_data.offersCount %> offers</span>
#                         </li>
#                     <% } %>
#                 </ul>
#             </div>
# 			<div style="text-align: right; position: absolute; bottom: 0px; right: 0px;">
# 			<p>
#                 <button onclick="window.open('<%= hotel_data.url %>'); event.stopPropagation();" style="padding: 0px 15px; height: 35px; font-size: 16px; font-weight: bold; background-color: #ff6d38; color: white; border: none; border-radius: 4px;">BOOK NOW</button>
#             </p>
# 			<p style="color: #ff3a5c; margin: 5px 0px;" class="htl-tile-last-opt"><%= hotel_data.lastTag %>&nbsp;</p>
# 		</div>
# 	</div>
# </div>
# </script><script type="text/javascript">
#     pageType = "main_city";
#     lat = 31.1048145;
#     lon = 77.1734033;
#     city_name = "Shimla";
#     city_id = "1449073512565742573";
#     currentHost = "voyager.goibibo.com";
#     allHotelsData = {};
#     allHermesData = {};
#     priortizedHotelIds = ["3335398829407382929", "3572747602679325734", "8269876364174459846", "4098314048100585768", "8351599671021854493", "3839912992465323263", "1416809721456220441", "1953288179585905793", "8689972586923762049", "8833337098196373625", "3972438790911577064", "5552266556689170547", "171304619761356672", "2739295705892554451", "6025344523708922203", "4603401151261891684", "5296367711267092596", "3882623631711451075", "7020693384946872874", "3027796615243425553", "6990212052173557682", "3451763848511086302", "2599470256323068721", "6320051737019986277", "323485704258300318", "6219607130473533931", "2233447007757316171", "7325499651138989507", "8871636629353578439", "6672745452248732216", "7353626981578665283", "2923574460049613062", "7729380753537016165", "3399253684009777930", "2107192302665896428", "7764296370836633209", "856240637447634495", "1769649039584828409", "6868601222461797927", "4899085585014300339", "5780866766883362606", "3687170931724471022", "7638770112293463188", "7393074725561129529", "6464896238536546864", "2229265802353322488", "3816266321977187845", "4637820275887385447", "8964443484484594838", "3464718552129675150", "7190057949854954330", "3896020271608532948", "7899035935330867108", "5035039896502133936", "8970639597040984344", "2866704395127249073", "3122448041086811088", "4917911572303765618", "8474581889215348193", "5937000712051274523", "4430673730811884875", "894231724514839263", "5884068027977565082", "4239247513600019158", "7798423028228869013", "7330523828712648537", "5835460537096667117", "2610176761536433856", "9191986948655858497", "5226089337385666229", "3690070650907013712", "4508640287885363792", "1840384582126692352", "7905287361581001648", "4354553821466644453", "5231879829398869129", "4132340955783784970", "7131765730681137", "4270473854139036574", "2264529271423614038", "9132401001922838353", "8005471583658990261", "7233073256399800597", "6582857422120530423", "4263883128813072657", "6833650235336324497", "2311532179286816502", "5243132854159319848", "7696013012067250540", "3394214965776349887", "1566559072649220797", "3754327080378501221", "4093584789369691896", "912580186579670511", "3861576060139081035", "3369629136120637174", "5385649342683345731", "4258159895502405979", "1789574127882284322", "3881044184948929280", "1923769941457192394", "5513812841692411131", "994303966553207628", "8685198985434721970", "2724952418138578682", "1490819890186447857", "289297441951257782", "4440839263471650198", "5751358002235918388", "1449963254462068403", "9186820163445991802", "909705468737555211", "8841426569839680445", "8875423732210384017", "5688410952616404300", "703198957683152393", "5018372624023522038", "5254749793973848546", "4851345145442551410", "9087118454481438872", "736425363845889208", "1978269669167048330", "584566816388311754", "2668930289000053794", "5860465706634300818", "1396176694547032016", "828693841156692241", "2722835239411954969", "1770849336303147771", "8666859306929546981", "6852595141618416754", "6956831556773249795", "6992592702406338805", "926642424978302912", "5573441308814972871", "2706073311959172046", "518705267460558983", "6045723022250842323", "4374345064866095428", "2930265219565893244", "9120729130081272183", "2904039471881741147", "2101487170542506404", "552382346639660862", "6950680197781245899", "7459202266562597344", "2805366558683576001", "8525376831693729270", "6617236183435430076", "2865955665055037007", "5914857255039358309", "7748517147424994306", "1700844874317530146", "7734814358727015024", "252857928419426098", "6467213783512500824", "7298978233884888768", "6849717144312925906", "7309046686498622248", "4046156333192759668", "8926765172084866206", "7847646803364735412", "3739938819293799336", "558721217826305007", "2879786154839466132", "5490941750412315350", "5644494538551280914", "5517880062258498397", "7071577211857429914", "441747302991298674", "468716359006925408", "2572441171192798856", "3436642880906825535", "3334665526982113 ...
#     priortizedHotelIdsSlice = ["3335398829407382929", "3572747602679325734", "8269876364174459846", "4098314048100585768", "8351599671021854493", "3839912992465323263", "1416809721456220441", "1953288179585905793", "8689972586923762049", "8833337098196373625", "8875423732210384017", "3399253684009777930", "8685198985434721970", "2865955665055037007", "3451763848511086302", "2599470256323068721", "7353626981578665283", "6689307888477876134", "6868601222461797927"];
#
#     recentlyReviewedHotelIds = ["7353626981578665283", "6689307888477876134", "6868601222461797927"];
#     recentlyBookedHotelIds = ["2865955665055037007", "3451763848511086302", "2599470256323068721"];
#     allHotelIds = priortizedHotelIds.concat(recentlyReviewedHotelIds)
#     allHotelIds = allHotelIds.concat(recentlyBookedHotelIds)
#     hotelAmenitiesNames = {"Free Internet": 112, "Outdoor Activities": 108, "CCTV surveillance": 119, "Dining": 120, "Internet": 105, "Conference Room": 125, "Air Conditioning": 126, "Power backup": 123, "Swimming Pool": 101, "Banquet hall": 124, "Clean Room": 115, "Travel Assistance": 109, "Indoor Entertainment": 111, "Kitchen": 128, "Front desk": 107, "Clean linen": 118, "Laundry Service": 110, "Business Services": 104, "Health-Spa": 106, "Parking Facility": 103, "Bonfire": 129, "Private Pool": 127, "Airport Transfer (on Demand)": 121, "Room Service": 113, "Restaurant/Coffee Shop": 102, "Pets allowed": 122, "Smoking Rooms Available": 116, "Spa": 114, "Daily housekeeping": 130, "Clean Washroom": 117};
#     ugcAmenitiesMapping = {"vfm_rating": {"name": "Value for Money", "icon": "mnyIconMob"}, "fd_rating": {"name": "Food & Drinks", "icon": "fdIconMob"}, "loc_rating": {"name": "Location", "icon": "loctnIconMob"}, "sq_rating": {"name": "Service & Quality", "icon": "qltyIconMob"}, "cleanliness_rating": {"name": "Cleanliness", "icon": "clnIconMob"}, "amenities_rating": {"name": "Amenities", "icon": "amntyIconMob"}};
#     location_area_name = "";
#     hotel_city_name = "shimla";
#     chain_code = "";
#
#     star_rating = "";
#
#     property_type = "Hotels";
#     recommendedHotelIds = []
#     showLocationBox = true
#
#     location_id = ""
#     currentPage = 1;
#     loadLock = false;
#     locations = [];
#     landmarks = [];
#     contextTotalPages = 0;
#     distanceMapData = {};
#     collecName = "";
#     collecId = "";
#     segmentsRedirectSlugMap = {"763": {"url": "https://www.goibibo.com/hotels/hotels-for-couples-in-shimla-cl/", "collec_name": "dh_cf", "collec_id": "763"}, "766": {"url": "https://www.goibibo.com/hotels/business-hotels-in-shimla-cl/", "collec_name": "dh_business_friendly", "collec_id": "766"}, "5421": {"url": "https://www.goibibo.com/hotels/resorts-in-shimla-cl/", "collec_name": "resorts_landmark_location", "collec_id": "5421"}, "749": {"url": "https://www.goibibo.com/hotels/gostays-in-shimla-cl/", "collec_name": "dh_gostays", "collec_id": "749"}};
#
#     for (var id in segmentsRedirectSlugMap) {
# ...
#
#
#         chains = [{"url": "/hotels/hotels-in-shimla/oyo-rooms-oyorms-chain/", "count": 172, "img": "https://gos3.ibcdn.com/OYO_Rooms-1424340877.jpg", "n": "OYO Rooms"}, {"url": "/hotels/hotels-in-shimla/vista-rooms-vistarms-chain/", "count": 10, "img": "", "n": "Vista Rooms"}, {"url": "/hotels/hotels-in-shimla/zostel-zostel-chain/", "count": 4, "img": "", "n": "Zostel"}, {"url": "/hotels/hotels-in-shimla/hptdc-hptdc-chain/", "count": 4, "img": "", "n": "HPTDC"}, {"url": "/hotels/hotels-in-shimla/leisure-hotels-leisurehtl-chain/", "count": 3, "img": "https://gos3.ibcdn.com/LeisureHotels-1423739810.jpg", "n": "Leisure Hotels"}, {"url": "/hotels/hotels-in-shimla/club-mahindra-group-clubmhndrg-chain/", "count": 3, "img": "https://gos3.ibcdn.com/Club_Mahindra_Group-1424342342.png", "n": "Club Mahindra Group"}];
#
#
#     var enhancedEcommerceEvent = {};
#     var pos = 1;
#
#         var event_info = {}
#
#     var category = "hotels-domestic";
#     var end_page = 10;
#     var start_page = 1;
#     var subCategory = "domestic";
#
#     var hotelSoContext = {"hid": null};
#     var recommendedHotels = [];
#     enhancedEcommerceEvent['event'] = "enhanced-ecommerce-srp";
#     enhancedEcommerceEvent['path'] = window.location.href;
#     enhancedEcommerceEvent['client'] = "client";
#     enhancedEcommerceEvent['ecommerce'] = {"impressions":[]};
#     var roomString = "1-2_0";
#
#
#             enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Hotel Mayur","id":"7353626981578665283","brand":"","category":category,"price":1600,"variant":3,"position":pos,"list":ecommerceListType });
#             pos++;
#
#             enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"OYO Home 10165 Snow View 2BHK","id":"6689307888477876134","brand":"","category":category,"price":2118,"variant":3,"position":pos,"list":ecommerceListType });
#             pos++;
#
#             enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Snow Lotus","id":"6868601222461797927","brand":"","category":category,"price":2400,"variant":3,"position":pos,"list":ecommerceListType });
#             pos++;
#
#
#
#
#
#             enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Koti Resorts","id":"2865955665055037007","brand":"","category":category,"price":4800,"variant":4,"position":pos,"list":ecommerceListType });
#             pos++;
#
#             enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Hotel Chaman Palace","id":"3451763848511086302","brand":"","category":category,"price":1500,"variant":3,"position":pos,"list":ecommerceListType });
#             pos++;
#
#             enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Hotel Sidharath","id":"2599470256323068721","brand":"","category":category,"price":2800,"variant":3,"position":pos,"list":ecommerceListType });
#             pos++;
#
#
#
#
#
#
#                 enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"The Rock Castle","id":"3335398829407382929","brand":"","category":category,"price":2275,"variant":4,"position":pos,"list":ecommerceListType });
#                 pos++;
#
#
#
#                 enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Hotel Combermere","id":"3572747602679325734","brand":"","category":category,"price":6560,"variant":4,"position":pos,"list":ecommerceListType });
#                 pos++;
#
#
#
#                 enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Hotel Dalziel","id":"8269876364174459846","brand":"","category":category,"price":1620,"variant":3,"position":pos,"list":ecommerceListType });
#                 pos++;
#
#
#
#                 enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Hotel Willow Banks","id":"4098314048100585768","brand":"","category":category,"price":6396,"variant":4,"position":pos,"list":ecommerceListType });
#                 pos++;
#
#
#
#                 enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"landmark shimla - With Elevator Access To Mall Road","id":"8351599671021854493","brand":"","category":category,"price":3120,"variant":4,"position":pos,"list":ecommerceListType });
#                 pos++;
#
#
#
#                 enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Summit Thistle Villa Resort &amp; Spa","id":"3839912992465323263","brand":"","category":category,"price":3480,"variant":4,"position":pos,"list":ecommerceListType });
#                 pos++;
#
#
#
#                 enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Amritara The Zion Hotel","id":"1416809721456220441","brand":"","category":category,"price":4900,"variant":4,"position":pos,"list":ecommerceListType });
#                 pos++;
#
#
#
#                 enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Snow Valley Resorts","id":"1953288179585905793","brand":"","category":category,"price":3600,"variant":4,"position":pos,"list":ecommerceListType });
#                 pos++;
#
#
#
#                 enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Hotel Shingar","id":"8689972586923762049","brand":"","category":category,"price":3040,"variant":3,"position":pos,"list":ecommerceListType });
#                 pos++;
#
#
#
#                 enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Marina- Shimla First Designer Boutique Hotel","id":"8833337098196373625","brand":"","category":category,"price":6480,"variant":5,"position":pos,"list":ecommerceListType });
#                 pos++;
#
#
#
#
#
#
#     // get list of locations and landmark ids
#
#     locationIdsList = [];
#     landmarkIdsList = [];
#
#     for (var i = 0; i < locations.length; i++) {
#         locationIdsList.push(locations[i]['id'])
#     }
#     for (var i = 0; i < landmarks.length; i++) {
#         landmarkIdsList.push(landmarks[i]['id'])
#     }
# </script><script src="//voyager.goibibo.com/static/cache/js/739d09befd0a.js" type="text/javascript"></script><style type="text/css">.fotDPLink a { color: #b3b3b3; font-size: 12px; line-height: 1; float: left; margin-right: 5px; padding-bottom: 5px; } .greyLter { color: #b3b3b3; } .website-badge-Bottom{display:none!important;}</style><div class="footerBox mobdn posRel" style="z-index: 1;"><div class="website-badge-Bottom"></div><div class="marginAuto"><div class="col-md-12 col-sm-12 padB20"><ul class="col-md-2 col-sm-3 footerLinks"><li class="txtTransUpper font12 greyDr fb padB10">our products</li><li><a href="/flight-schedule/">Flight Schedule</a></li><li><a href="/flights/city-to-city-airlines/">City Airline Routes</a></li><li><a href="/international-flights/">International Flights</a></li><li><a href="/hotels-international/">International Hotels</a></li><li><a href="/bus/">Bus Booking</a></li><li><a href="/airlines/">Domestic Airlines</a></li><li><a href="/hotels/hotels-in-india/">Hotels in India</a></li><li><a href="/hotels/">Hotel Booking</a></li><li><a href="/flights/cheap-flights/">Cheap Flights</a></li><li class="txtTransUpper font12 greyDr fb padB10 marginT15">Company</li><li><a href="/aboutus/">About Us</a></li><li><a href="/faqs/">FAQs</a></li><li><a href="/terms-and-conditions/">Terms &amp; Conditions</a></li><li><a href="/common/privacy/">Privacy</a></li><li><a href="/contactus/">Contact Us</a></li><li><a href="http://www.ibibo.com/">ibibo Group</a></li></ul><ul class="col-md-2 col-sm-3 footerLinks"><li class="txtTransUpper font12 greyDr fb padB10">Trending Hotel Cities</li><li><a href="//www.goibibo.com/hotels/hotels-in-goa-ct/">Hotels in Goa</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-delhi-ct/">Hotels in Delhi</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-mumbai-ct/">Hotels in Mumbai</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-bengaluru-ct/">Hotels in Bengaluru</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-chennai-ct/">Hotels in Chennai</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-hyderabad-ct/">Hotels in Hyderabad</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-jaipur-ct/">Hotels in Jaipur</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-pondicherry-ct/">Hotels in Pondicherry</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-agra-ct/">Hotels in Agra</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-digha-ct/">Hotels in Digha</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-coimbatore-ct/">Hotels in Coimbatore</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-guwahati-ct/">Hotels in Guwahati</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-lucknow-ct/">Hotels in Lucknow</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-raipur-ct/">Hotels in Raipur</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-gurgaon-ct/">Hotels in Gurgaon</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-kochi-ct/">Hotels in Kochi</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-varanasi-ct/">Hotels in Varanasi</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-chandigarh-ct/">Hotels in Chandigarh</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-alibag-ct/">Hotels in Alibag</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-bhubaneswar-ct/">Hotels in Bhubaneswar</a></li></ul><ul class="col-md-2 col-sm-3 footerLinks"><li class="txtTransUpper font12 greyDr fb padB10">Trending International Hotel Cities</li><li><a href="//www.goibibo.com/hotels/intl-hotels-in-dubai-ct/">Hotels in Dubai</a></li><li><a href="//www.goibibo.com/hotels/intl-hotels-in-bangkok-ct/">Hotels in Bangkok</a></li><li><a href="//www.goibibo.com/hotels/intl-hotels-in-bali-ct/">Hotels in Bali</a></li><li><a href="//www.goibibo.com/hotels/intl-hotels-in-singapore-ct/">Hotels in Singapore</a></li><li><a href="//www.goibibo.com/hotels/intl-hotels-in-pattaya-ct/">Hotels in Pattaya</a></li><li><a href="//www.goibibo.com/hotels/intl-hotels- ...
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer', 'GTM-NNFJ8WW' );</script><script type="text/javascript">
#     var _gaq = _gaq || {};
#     var dataLayer = dataLayer || {};
#     var gaDevice = "desktop";
#
# </script><script type="text/javascript">
#     function pushEventToGA(category,action,label){
#         if(_gaq && _gaq.push)
#         {
#             var eventData = (label && label!=null) ? ['_trackEvent', category, action, label] : ['_trackEvent', category, action];
#             _gaq.push(eventData);
#         }
#
#     }
# </script><script type="text/javascript">
#     function createCookie(name,value,time) {
#         if (time) {
#             var date = new Date();
#             date.setTime(date.getTime()+(time*1000));
#             var expires = "; expires="+date.toGMTString();
#         }
#         else var expires = "";
#         document.cookie = name+"="+value+expires+"; path=/";
#     }
#
#     function readCookie(name) {
#         var nameEQ = name + "=";
#         var ca = document.cookie.split(';');
#         for(var i=0;i < ca.length;i++) {
#             var c = ca[i];
#             while (c.charAt(0)==' ') c = c.substring(1,c.length);
#             if (c.indexOf(nameEQ) == 0) return c.substring(nameEQ.length,c.length);
#         }
#         return null;
#     }
#
#     function eraseCookie(name) {
#         createCookie(name,"",-1);
#     }
#
#
#     function setAppInstallWidget(){
#         $("#app-install-widget").html('<div class="mobileApp" style="background-color:#f7f7f7;padding:10px 5px;"><div class="fl crossTop" style="width:5%;margin-right:1%;"><a href="javascript:void(0);" onclick="$(\'#app-install-widget\').slideUp();"><img src="//goibibo.ibcdn.com/images/mobile/apparrow.png" style="width:14px;"></a></div><div class="fl" style="width:94%;margin-top:-5px;"><a href="https://go.onelink.me/2118851199?pid=SEO&c=SEO_Banners" id="appFlyer"><div class="fl" style="margin-right:12px; color:#737373;font-size:14px;line-height:22px;"><div style="font-size:22px; color:#000;"><div class="fl"><img src="//goibibo.ibcdn.com/images/mobile/go_icon.png"></div><div class="fl" style="margin-top:5px;margin-left:5px;">Goibibo <img src="//goibibo.ibcdn.com/images/mobile/android_stars.png"></div></div><div style="clear:both;"></div><p>For more discounts and better experience download goibibo app.<span style="border-radius:3px;float:none;background-color:#2e69b3;color:#fff;padding:5px 10px;margin-left:10px;">Install</span></p></div><div class="clearAll"></div></a></div><div class="clearAll"></div></div>');
#     }
#
#     $(window).load(function(){
#         var seobanner = true;
#         location.search.substr(1).split("&").forEach(function (item) {
#             tmp = item.split("=");
#             if (tmp[0] === "flavour" && (tmp[1] === "android" || tmp[1] === "ios") )
#                 seobanner = false;
#                 });
#
#
#         if($(window).width()<600 && !readCookie("app_install_widget_seo") && seobanner){
#
#             createCookie("app_install_widget_seo",1,15*60);
#
#         }
#     })
#
#     function pushDataLayerEvent(eventData){
#         if(dataLayer && dataLayer.push)
#         {
#             dataLayer.push(eventData);
#         }
#
#     }
#
#
# </script><input name="pgt" type="hidden" value="06-02-2020 17:04:55"/><a class="btn-scroll-top dn" id="scroll-top-btn"></a><div id="login-div" style="display: none;"><div class="popOverlay popShow"></div><div class="popModal zoom small popShow" id="authOverlay"><div class="popContent"><a class="fr icon-close font12Lt popClose" href="javascript:void(0)" onclick="$('#login-div').hide()"></a><div class="popBody"><iframe height="480px" id="authiframe" src="about:blank" width="100%"></iframe></div></div></div></div><div class="padT10 width10 dn" id="missing-review"><span>Be the first Reviewer</span> <br/> <a class="blue font13" id="write-review">Write Reviews</a> <a class="blue fr font13" id="ask-questions">Ask Questions</a></div></body></html>

# %%
# find all the sections with specifiedd class name
cards_data = data.find_all('div', attrs={'class', 'width100 fl htlListSeo hotel-tile-srp-container hotel-tile-srp-container-template new-htl-design-tile-main-block'})

# %%
# total number of cards
print('Total Number of Cards Found : ', len(cards_data))
# Out:
# ('Total Number of Cards Found : ', 10)

# %%
# source code of hotel cards
for card in cards_data:
    print(card)
# Out:
# <div class="width100 fl htlListSeo hotel-tile-srp-container hotel-tile-srp-container-template new-htl-design-tile-main-block" id="htl-3335398829407382929" onclick="window.open('https://www.goibibo.com/hotels/the-rock-castle-hotel-in-shimla-3335398829407382929/');event.stopPropagation();"><div class="hotel-tile-srp-container-img-container"><div class="htl-tile-free-bkfst-overlay"><div class="text-label">Free breakfast</div><div class="label-decor"></div></div><div class="hotel-tile-srp-container-title-image"><img alt="The Rock Castle - Main Town, Shimla, Shimla" class="lazy" id="htl-tile-main-image-3335398829407382929" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" ori="https://cdn1.goibibo.com/t_g_ing_v8/rock-castle-shimla-parking-79969893214-orijgp.jpg" pagespeed_url_hash="2618872316" src="https://cdn1.goibibo.com/t_g_ing_v8/rock-castle-shimla-parking-79969893214-orijgp.jpg"/></div><ul class="hotel-tile-srp-container-image-gallery"><li><img alt="Hotel Images" class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/t_g3_ing_v9/the-rock-castle-shimla-1473079209692jpg-124131558590-orijgp.jpg" htl="3335398829407382929" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="2694139208" src="https://cdn1.goibibo.com/t_r_v3/the-rock-castle-shimla-1473079209692jpg-124131558590-orijgp.jpg"/></li><li><img alt="Hotel Images" class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/t_g3_ing_v9/the-rock-castle-shimla-1473079282843jpg-124131643955-orijgp.jpg" htl="3335398829407382929" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="2756510181" src="https://cdn1.goibibo.com/t_r_v3/the-rock-castle-shimla-1473079282843jpg-124131643955-orijgp.jpg"/></li><li><img alt="Hotel Images" class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/t_g3_ing_v9/the-rock-castle-shimla-1473078716845jpg-124131415721-orijgp.jpg" htl="3335398829407382929" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="2231839838" src="https://cdn1.goibibo.com/t_r_v3/the-rock-castle-shimla-1473078716845jpg-124131415721-orijgp.jpg"/></li><li><img alt="Hotel Images" class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/t_g3_ing_v9/the-rock-castle-shimla-1473078800799jpg-124131487089-orijgp.jpg" htl="3335398829407382929" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="2801232708" src="https://cdn1.goibibo.com/t_r_v3/the-rock-castle-shimla-1473078800799jpg-124131487089-orijgp.jpg"/></li><li><div style="cursor:pointer !important;">VIEW ALL</div><img alt="Hotel Images" class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/t_g3_ing_v9/rock-castle-shimla-img-20151221-wa0041-79893808991-orijgp.jpg" htl="3335398829407382929" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="2380966883" src="https://cdn1.goibibo.com/t_r_v3/rock-castle-shimla-img-20151221-wa0041-79893808991-orijgp.jpg"/></li></ul></div><div class="hotel-tile-srp-container-content-container"><ul class="hotel-content-container-top-hinged-list"><li><div style="display: inline-block;"><i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <span style="padding: 2px; border: 1px solid #e5edf6; border-radius: 2px; margin-left: 5px; color: #4f525a">HOTEL</span></div><div style="float: right; margin-right:8px; margin-top:3px;"><span>551 reviews</span> <span style="padding: 4px; background-color: #7ccf50; color: white; border-radius: 2px; margin-left: 5px;">4.3/5</span></div></li><li><a href="https://www.goibibo.com/hotels/the-rock-castle-hotel-in-shimla-3335398829407382929/" onclick="event.stopPropagation();" target="_blank"><p style="font-size: 18px; font-weight: bolder; ...
# <div class="width100 fl htlListSeo hotel-tile-srp-container hotel-tile-srp-container-template new-htl-design-tile-main-block" id="htl-3572747602679325734" onclick="window.open('https://www.goibibo.com/hotels/combermere-hotel-in-shimla-3572747602679325734/');event.stopPropagation();"><div class="hotel-tile-srp-container-img-container"><div class="htl-tile-free-bkfst-overlay"><div class="text-label">Free breakfast</div><div class="label-decor"></div></div><div class="hotel-tile-srp-container-title-image"><img alt="Hotel Combermere - The Mall Road, Shimla" class="lazy" id="htl-tile-main-image-3572747602679325734" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" ori="https://gos3.ibcdn.com/hotel-combermere-shimla-hotel-fecade-66170888922g.jpg" pagespeed_url_hash="2192931302" src="https://gos3.ibcdn.com/hotel-combermere-shimla-hotel-fecade-66170888922g.jpg"/></div></div><div class="hotel-tile-srp-container-content-container"><ul class="hotel-content-container-top-hinged-list"><li><div style="display: inline-block;"><i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <span style="padding: 2px; border: 1px solid #e5edf6; border-radius: 2px; margin-left: 5px; color: #4f525a">HOTEL</span></div><div style="float: right; margin-right:8px; margin-top:3px;"><span>820 reviews</span> <span style="padding: 4px; background-color: #7ccf50; color: white; border-radius: 2px; margin-left: 5px;">4.1/5</span></div></li><li><a href="https://www.goibibo.com/hotels/combermere-hotel-in-shimla-3572747602679325734/" onclick="event.stopPropagation();" target="_blank"><p style="font-size: 18px; font-weight: bolder; color: #141823;font-family: 'Quicksand', sans-serif;">Hotel Combermere</p></a></li><li style="color: #2276e3;"><p>The Mall Road, Shimla</p></li></ul><ul class="hotel-content-container-bottom-hinged-list"><li><i class="icon-ranking" style="font-size: 15px; margin-right: 3px; color: #fdba00"></i> <span class="htl-tile-top-tag-text" style="color: #2276e3; cursor: pointer">88% Guests recommend this hotel</span></li><li class="hotel-content-container-li-loc-usp" style=""><i class="icon-persuation-generic" style="font-size: 15px; margin-right: 3px;"></i> <span class="htl-tile-loc-pin-text"></span></li><li class="htl-tile-amenities-list" style=""><div style=""><i class="icon-service2" style=""></i> <span>Room Service</span></div><div style=""><i class="icon-restaurant2" style=""></i> <span>Restaurant/Coffee Shop</span></div><span style="color: #2276e3; cursor: pointer">+ 11 More</span></li><li style="color: #ff3a5c;"><i class="icon-couple-man-woman" style="font-size: 15px; margin-right: 3px;"></i> <span>Couple Friendly</span></li><li style="color: #861388; display: none"><span><i class="icon-steal-deal" style="font-size: 15px; margin-right: 3px;"></i></span> <span style="padding: 3px 8px; border-radius: 10px; background-color: #f2e7f3;">Steal Deal</span> <span class="htl-tile-steal-deal-text" style="margin-left: 5px; color: black;"></span></li></ul></div><div style="width: 200px; margin: 12px 10px 0px 6px; display: inline-block; border-left: 1px solid #e5edf6; height: 256px; position: absolute; right: 0px; font-size: 12px; color: #4f525a;"><div style="display: none; font-size: 12px; font-weight: bold; position: absolute; top: -24px; right: 10px;"><div style="display: inline-block; width: 0px; height: 0px; border-right: 5px solid #898b91; border-left: 5px solid transparent; border-top: 5px solid transparent; border-bottom: 5px solid #898b91; margin: -9px 0px 0px 0px;"></div><div class="htl-tile-banner-text-div" style="display: inline-block; padding: 1px 10px; background-image: linear-gradient(284deg, #adaeb2, #34393a); color: white; width: max-content; border-bottom-right-radius: 2px; border-bottom-left-radius: 2px; heigh ...
# <div class="width100 fl htlListSeo hotel-tile-srp-container hotel-tile-srp-container-template new-htl-design-tile-main-block" id="htl-8269876364174459846" onclick="window.open('https://www.goibibo.com/hotels/dalziel-hotel-in-shimla-8269876364174459846/');event.stopPropagation();"><div class="hotel-tile-srp-container-img-container"><div class="htl-tile-free-bkfst-overlay"><div class="text-label">Free breakfast</div><div class="label-decor"></div></div><div class="hotel-tile-srp-container-title-image"><img alt="Hotel Dalziel - The Mall Road, Shimla" class="lazy" id="htl-tile-main-image-8269876364174459846" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" ori="https://cdn1.goibibo.com/t_g_ing_v8/hotel-dalziel-shimla-lobby-115068775954-orijgp.jpg" pagespeed_url_hash="1994287727" src="https://cdn1.goibibo.com/t_g_ing_v8/hotel-dalziel-shimla-lobby-115068775954-orijgp.jpg"/></div><ul class="hotel-tile-srp-container-image-gallery"><li><img alt="Hotel Images" class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/t_g3_ing_v9/hotel-dalziel-shimla-reception-area-167085996884-orijgp.jpg" htl="8269876364174459846" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="2877096620" src="https://cdn1.goibibo.com/t_r_v3/hotel-dalziel-shimla-reception-area-167085996884-orijgp.jpg"/></li><li><img alt="Hotel Images" class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/t_g3_ing_v9/hotel-dalziel-shimla-family-room-145027926936-orijgp.jpg" htl="8269876364174459846" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1037621192" src="https://cdn1.goibibo.com/t_r_v3/hotel-dalziel-shimla-family-room-145027926936-orijgp.jpg"/></li><li><img alt="Hotel Images" class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/t_g3_ing_v9/hotel-dalziel-shimla-201405271746231675_hotel-dalziel_super-deluxe-bathroom_image2jpg-112875277963-orijgp.jpg" htl="8269876364174459846" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="2393987116" src="https://cdn1.goibibo.com/t_r_v3/hotel-dalziel-shimla-201405271746231675_hotel-dalziel_super-deluxe-bathroom_image2jpg-112875277963-orijgp.jpg"/></li><li><img alt="Hotel Images" class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/t_g3_ing_v9/hotel-dalziel-shimla-lobby-115068775954-orijgp.jpg" htl="8269876364174459846" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="4162559180" src="https://cdn1.goibibo.com/t_r_v3/hotel-dalziel-shimla-lobby-115068775954-orijgp.jpg"/></li><li><div style="cursor:pointer !important;">VIEW ALL</div><img alt="Hotel Images" class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/image/fetch/t_g3_ing_v9/f_jpg/http://mdb.ibcdn.com/4045c9c4812a11e4b94436cfdd80c293.jfif" htl="8269876364174459846" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="2310303579" src="https://cdn1.goibibo.com/image/fetch/t_r_v3/f_jpg/http://mdb.ibcdn.com/4045c9c4812a11e4b94436cfdd80c293.jfif"/></li></ul></div><div class="hotel-tile-srp-container-content-container"><ul class="hotel-content-container-top-hinged-list"><li><div style="display: inline-block;"><i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <span style="padding: 2px; border: 1px solid #e5edf6; border-radius: 2px; margin-left: 5px; color: #4f525a">HOTEL</span></div><div style="float: right; margin-right:8px; margin-top:3px;"><span>1296 reviews</span> <span style="padding: 4px; background-color: #7ccf50; color: white; border-radius: 2px; margin-left: 5px;">4.0/5</span></div></li><li><a href="https://www.goibibo.com/hotels/dalziel-hotel-in-shimla-8269876364174459846/" onclick="event.stopPropagation();" target="_blank"><p style="font-size: 18px; font-weight: bolder; color: #1418 ...
# <div class="width100 fl htlListSeo hotel-tile-srp-container hotel-tile-srp-container-template new-htl-design-tile-main-block" id="htl-4098314048100585768" onclick="window.open('https://www.goibibo.com/hotels/willow-banks-hotel-in-shimla-4098314048100585768/');event.stopPropagation();"><div class="hotel-tile-srp-container-img-container"><div class="htl-tile-free-bkfst-overlay"><div class="text-label">Free breakfast</div><div class="label-decor"></div></div><div class="hotel-tile-srp-container-title-image"><img alt="Hotel Willow Banks - The Mall Road, Shimla" class="lazy" id="htl-tile-main-image-4098314048100585768" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" ori="https://cdn1.goibibo.com/t_g_ing_v8/hotel-willow-banks-shimla-hotel-facade-106399262964-orijgp.jpg" pagespeed_url_hash="3188564940" src="https://cdn1.goibibo.com/t_g_ing_v8/hotel-willow-banks-shimla-hotel-facade-106399262964-orijgp.jpg"/></div><ul class="hotel-tile-srp-container-image-gallery"><li><img alt="Hotel Images" class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/t_g3_ing_v9/hotel-willow-banks-shimla-hotel-facade-106399262964-orijgp.jpg" htl="4098314048100585768" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="3453318745" src="https://cdn1.goibibo.com/t_r_v3/hotel-willow-banks-shimla-hotel-facade-106399262964-orijgp.jpg"/></li><li><div style="cursor:pointer !important;">VIEW ALL</div><img alt="Hotel Images" class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/image/fetch/t_g3_ing_v9/f_jpg/https://gos3.ibcdn.com/5e43b07c27af11ea9fd20242ac110002.jpg" htl="4098314048100585768" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="3017793726" src="https://cdn1.goibibo.com/image/fetch/t_r_v3/f_jpg/https://gos3.ibcdn.com/5e43b07c27af11ea9fd20242ac110002.jpg"/></li></ul></div><div class="hotel-tile-srp-container-content-container"><ul class="hotel-content-container-top-hinged-list"><li><div style="display: inline-block;"><i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <span style="padding: 2px; border: 1px solid #e5edf6; border-radius: 2px; margin-left: 5px; color: #4f525a">HOTEL</span></div><div style="float: right; margin-right:8px; margin-top:3px;"><span>763 reviews</span> <span style="padding: 4px; background-color: #7ccf50; color: white; border-radius: 2px; margin-left: 5px;">4.1/5</span></div></li><li><a href="https://www.goibibo.com/hotels/willow-banks-hotel-in-shimla-4098314048100585768/" onclick="event.stopPropagation();" target="_blank"><p style="font-size: 18px; font-weight: bolder; color: #141823;font-family: 'Quicksand', sans-serif;">Hotel Willow Banks</p></a></li><li style="color: #2276e3;"><p>The Mall Road, Shimla</p></li></ul><ul class="hotel-content-container-bottom-hinged-list"><li><i class="icon-ranking" style="font-size: 15px; margin-right: 3px; color: #fdba00"></i> <span class="htl-tile-top-tag-text" style="color: #2276e3; cursor: pointer">89% Guests recommend this hotel</span></li><li class="hotel-content-container-li-loc-usp" style=""><i class="icon-persuation-generic" style="font-size: 15px; margin-right: 3px;"></i> <span class="htl-tile-loc-pin-text"></span></li><li class="htl-tile-amenities-list" style=""><div style=""><i class="icon-service2" style=""></i> <span>Room Service</span></div><div style=""><i class="icon-restaurant2" style=""></i> <span>Restaurant/Coffee Shop</span></div><span style="color: #2276e3; cursor: pointer">+ 14 More</span></li><li style="color: #ff3a5c;"><i class="icon-couple-man-woman" style="font-size: 15px; margin-right: 3px;"></i> <span>Couple Friendly</span></li><li style="color: #861388; display: none"><span><i class="icon-steal-deal" style="font-size: 15px; margin-right: 3px;" ...
# <div class="width100 fl htlListSeo hotel-tile-srp-container hotel-tile-srp-container-template new-htl-design-tile-main-block" id="htl-8351599671021854493" onclick="window.open('https://www.goibibo.com/hotels/landmark-shimla-with-elevator-access-to-mall-road-hotel-in-shimla-8351599671021854493/');event.stopPropagation();"><div class="hotel-tile-srp-container-img-container"><div class="htl-tile-free-bkfst-overlay"><div class="text-label">Free breakfast</div><div class="label-decor"></div></div><div class="hotel-tile-srp-container-title-image"><img alt="landmark shimla - With Elevator Access To Mall Road - The Mall Road, Shimla" class="lazy" id="htl-tile-main-image-8351599671021854493" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" ori="https://cdn1.goibibo.com/t_g_ing_v8/landmark-shimla-with-elevator-access-to-mall-road-shimla-facade-149434255080-orijgp.jpg" pagespeed_url_hash="1386695934" src="https://cdn1.goibibo.com/t_g_ing_v8/landmark-shimla-with-elevator-access-to-mall-road-shimla-facade-149434255080-orijgp.jpg"/></div><ul class="hotel-tile-srp-container-image-gallery"><li><img alt="Hotel Images" class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/t_g3_ing_v9/landmark-shimla-with-elevator-access-to-mall-road-shimla-interior-2-166721727495-orijgp.jpg" htl="8351599671021854493" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="2763893764" src="https://cdn1.goibibo.com/t_r_v3/landmark-shimla-with-elevator-access-to-mall-road-shimla-interior-2-166721727495-orijgp.jpg"/></li><li><img alt="Hotel Images" class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/t_g3_ing_v9/landmark-shimla-with-elevator-access-to-mall-road-shimla-bedroom-2-149434261328-orijgp.jpg" htl="8351599671021854493" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="2925323534" src="https://cdn1.goibibo.com/t_r_v3/landmark-shimla-with-elevator-access-to-mall-road-shimla-bedroom-2-149434261328-orijgp.jpg"/></li><li><img alt="Hotel Images" class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/t_g3_ing_v9/landmark-shimla-with-elevator-access-to-mall-road-shimla-entrance-1-166721710108-orijgp.jpg" htl="8351599671021854493" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="3931415642" src="https://cdn1.goibibo.com/t_r_v3/landmark-shimla-with-elevator-access-to-mall-road-shimla-entrance-1-166721710108-orijgp.jpg"/></li><li><img alt="Hotel Images" class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/t_g3_ing_v9/hotel-landmark-shimla-super-deluxe-room-129391462254-orijgp.jpg" htl="8351599671021854493" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="369226628" src="https://cdn1.goibibo.com/t_r_v3/hotel-landmark-shimla-super-deluxe-room-129391462254-orijgp.jpg"/></li><li><div style="cursor:pointer !important;">VIEW ALL</div><img alt="Hotel Images" class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/t_g3_ing_v9/hotel-landmark-shimla-washroom-129391497334-orijgp.jpg" htl="8351599671021854493" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="3598740168" src="https://cdn1.goibibo.com/t_r_v3/hotel-landmark-shimla-washroom-129391497334-orijgp.jpg"/></li></ul></div><div class="hotel-tile-srp-container-content-container"><ul class="hotel-content-container-top-hinged-list"><li><div style="display: inline-block;"><i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <span style="padding: 2px; border: 1px solid #e5edf6; border-radius: 2px; margin-left: 5px; color: #4f525a">HOTEL</span></div><div style="float: right; margin-right:8px; margin-top:3px;"><span>2011 reviews</span> <span style="padding: 4px; backg ...
# <div class="width100 fl htlListSeo hotel-tile-srp-container hotel-tile-srp-container-template new-htl-design-tile-main-block" id="htl-3839912992465323263" onclick="window.open('https://www.goibibo.com/hotels/summit-thistle-villa-resort-spa-hotel-in-shimla-3839912992465323263/');event.stopPropagation();"><div class="hotel-tile-srp-container-img-container"><div class="htl-tile-free-bkfst-overlay"><div class="text-label">Free breakfast</div><div class="label-decor"></div></div><div class="hotel-tile-srp-container-title-image"><img alt="Summit Thistle Villa Resort &amp; Spa - Mashobra B, Shimla" class="lazy" id="htl-tile-main-image-3839912992465323263" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" ori="https://cdn1.goibibo.com/image/fetch/t_g_ing_v8/f_jpg/https://gos3.ibcdn.com/9341052ccf2611e99cdc0242ac110004.jpg" pagespeed_url_hash="423392116" src="https://cdn1.goibibo.com/image/fetch/t_g_ing_v8/f_jpg/https://gos3.ibcdn.com/9341052ccf2611e99cdc0242ac110004.jpg"/></div><ul class="hotel-tile-srp-container-image-gallery"><li><img alt="Hotel Images" class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/image/fetch/t_g3_ing_v9/f_jpg/https://gos3.ibcdn.com/a01b2a72ef5911e9a2b90242ac110002.jpg" htl="3839912992465323263" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="718232727" src="https://cdn1.goibibo.com/image/fetch/t_r_v3/f_jpg/https://gos3.ibcdn.com/a01b2a72ef5911e9a2b90242ac110002.jpg"/></li><li><img alt="Hotel Images" class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/image/fetch/t_g3_ing_v9/f_jpg/https://gos3.ibcdn.com/2f54b084ef5811e986f00242ac110006.jpg" htl="3839912992465323263" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="3387619385" src="https://cdn1.goibibo.com/image/fetch/t_r_v3/f_jpg/https://gos3.ibcdn.com/2f54b084ef5811e986f00242ac110006.jpg"/></li><li><img alt="Hotel Images" class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/image/fetch/t_g3_ing_v9/f_jpg/https://gos3.ibcdn.com/affbdc66ef5911e9b6780242ac110002.jpg" htl="3839912992465323263" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1916027298" src="https://cdn1.goibibo.com/image/fetch/t_r_v3/f_jpg/https://gos3.ibcdn.com/affbdc66ef5911e9b6780242ac110002.jpg"/></li><li><img alt="Hotel Images" class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/image/fetch/t_g3_ing_v9/f_jpg/https://gos3.ibcdn.com/f83102d6d18611e9bc4d0242ac110003.jpg" htl="3839912992465323263" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1361193053" src="https://cdn1.goibibo.com/image/fetch/t_r_v3/f_jpg/https://gos3.ibcdn.com/f83102d6d18611e9bc4d0242ac110003.jpg"/></li><li><div style="cursor:pointer !important;">VIEW ALL</div><img alt="Hotel Images" class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/image/fetch/t_g3_ing_v9/f_jpg/https://gos3.ibcdn.com/09d7673cef5a11e99e0e0242ac110002.jpg" htl="3839912992465323263" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1905563427" src="https://cdn1.goibibo.com/image/fetch/t_r_v3/f_jpg/https://gos3.ibcdn.com/09d7673cef5a11e99e0e0242ac110002.jpg"/></li></ul></div><div class="hotel-tile-srp-container-content-container"><ul class="hotel-content-container-top-hinged-list"><li><div style="display: inline-block;"><i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <span style="padding: 2px; border: 1px solid #e5edf6; border-radius: 2px; margin-left: 5px; color: #4f525a">RESORT</span></div><div style="float: right; margin-right:8px; margin-top:3px;"><span>144 reviews</span> <span style="padding: 4px; background-color: #7ccf50; color: white; border-radius: 2px; margin-l ...
# <div class="width100 fl htlListSeo hotel-tile-srp-container hotel-tile-srp-container-template new-htl-design-tile-main-block" id="htl-1416809721456220441" onclick="window.open('https://www.goibibo.com/hotels/amritara-the-zion-hotel-in-shimla-1416809721456220441/');event.stopPropagation();"><div class="hotel-tile-srp-container-img-container"><div class="htl-tile-free-bkfst-overlay"><div class="text-label">Free breakfast</div><div class="label-decor"></div></div><div class="hotel-tile-srp-container-title-image"><img alt="Amritara The Zion Hotel - Main Town, Shimla" class="lazy" id="htl-tile-main-image-1416809721456220441" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" ori="https://cdn1.goibibo.com/t_g_ing_v8/the-zion-an-amritara-resort-shimla-01-zion-165178881383-orijgp.jpg" pagespeed_url_hash="3192570938" src="https://cdn1.goibibo.com/t_g_ing_v8/the-zion-an-amritara-resort-shimla-01-zion-165178881383-orijgp.jpg"/></div><ul class="hotel-tile-srp-container-image-gallery"><li><img alt="Hotel Images" class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/t_g3_ing_v9/the-zion-an-amritara-resort-shimla-04-165178921615-orijgp.jpg" htl="1416809721456220441" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1580342776" src="https://cdn1.goibibo.com/t_r_v3/the-zion-an-amritara-resort-shimla-04-165178921615-orijgp.jpg"/></li><li><img alt="Hotel Images" class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/t_g3_ing_v9/the-zion-an-amritara-resort-shimla-lobby-120657928273-orijgp.jpg" htl="1416809721456220441" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="4151588266" src="https://cdn1.goibibo.com/t_r_v3/the-zion-an-amritara-resort-shimla-lobby-120657928273-orijgp.jpg"/></li><li><img alt="Hotel Images" class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/t_g3_ing_v9/the-zion-an-amritara-resort-shimla-01-zion-165178881383-orijgp.jpg" htl="1416809721456220441" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="551395543" src="https://cdn1.goibibo.com/t_r_v3/the-zion-an-amritara-resort-shimla-01-zion-165178881383-orijgp.jpg"/></li><li><img alt="Hotel Images" class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/t_g3_ing_v9/the-zion-an-amritara-resort-shimla-11-165178997484-orijgp.jpg" htl="1416809721456220441" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="252164657" src="https://cdn1.goibibo.com/t_r_v3/the-zion-an-amritara-resort-shimla-11-165178997484-orijgp.jpg"/></li><li><div style="cursor:pointer !important;">VIEW ALL</div><img alt="Hotel Images" class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/t_g3_ing_v9/the-zion-an-amritara-resort-shimla-08-165178963290-orijgp.jpg" htl="1416809721456220441" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1729774831" src="https://cdn1.goibibo.com/t_r_v3/the-zion-an-amritara-resort-shimla-08-165178963290-orijgp.jpg"/></li></ul></div><div class="hotel-tile-srp-container-content-container"><ul class="hotel-content-container-top-hinged-list"><li><div style="display: inline-block;"><i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <span style="padding: 2px; border: 1px solid #e5edf6; border-radius: 2px; margin-left: 5px; color: #4f525a">RESORT</span></div><div style="float: right; margin-right:8px; margin-top:3px;"><span>182 reviews</span> <span style="padding: 4px; background-color: #7ccf50; color: white; border-radius: 2px; margin-left: 5px;">4.6/5</span></div></li><li><a href="https://www.goibibo.com/hotels/amritara-the-zion-hotel-in-shimla-1416809721456220441/" onclick="event.stopPropagation();" target="_blank"><p style=" ...
# <div class="width100 fl htlListSeo hotel-tile-srp-container hotel-tile-srp-container-template new-htl-design-tile-main-block" id="htl-1953288179585905793" onclick="window.open('https://www.goibibo.com/hotels/snow-valley-resorts-hotel-in-shimla-1953288179585905793/');event.stopPropagation();"><div class="hotel-tile-srp-container-img-container"><div class="htl-tile-free-bkfst-overlay"><div class="text-label">Free breakfast</div><div class="label-decor"></div></div><div class="hotel-tile-srp-container-title-image"><img alt="Snow Valley Resorts - Main Town, Shimla" class="lazy" id="htl-tile-main-image-1953288179585905793" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" ori="https://cdn1.goibibo.com/image/fetch/t_g_ing_v8/f_jpg/https://gos3.ibcdn.com/1de95162354211e5bbab001ec9b85d13.jfif" pagespeed_url_hash="1352069900" src="https://cdn1.goibibo.com/image/fetch/t_g_ing_v8/f_jpg/https://gos3.ibcdn.com/1de95162354211e5bbab001ec9b85d13.jfif"/></div><ul class="hotel-tile-srp-container-image-gallery"><li><img alt="Hotel Images" class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/image/fetch/t_g3_ing_v9/f_jpg/https://gos3.ibcdn.com/e22cb0bc385511ea8a5b0242ac110004.jpg" htl="1953288179585905793" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="4178369962" src="https://cdn1.goibibo.com/image/fetch/t_r_v3/f_jpg/https://gos3.ibcdn.com/e22cb0bc385511ea8a5b0242ac110004.jpg"/></li><li><img alt="Hotel Images" class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/image/fetch/t_g3_ing_v9/f_jpg/https://gos3.ibcdn.com/38c1ee2a385511ea8dcc0242ac11000a.jpg" htl="1953288179585905793" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1442105786" src="https://cdn1.goibibo.com/image/fetch/t_r_v3/f_jpg/https://gos3.ibcdn.com/38c1ee2a385511ea8dcc0242ac11000a.jpg"/></li><li><div style="cursor:pointer !important;">VIEW ALL</div><img alt="Hotel Images" class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/image/fetch/t_g3_ing_v9/f_jpg/https://gos3.ibcdn.com/1de95162354211e5bbab001ec9b85d13.jfif" htl="1953288179585905793" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="3855408377" src="https://cdn1.goibibo.com/image/fetch/t_r_v3/f_jpg/https://gos3.ibcdn.com/1de95162354211e5bbab001ec9b85d13.jfif"/></li></ul></div><div class="hotel-tile-srp-container-content-container"><ul class="hotel-content-container-top-hinged-list"><li><div style="display: inline-block;"><i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <span style="padding: 2px; border: 1px solid #e5edf6; border-radius: 2px; margin-left: 5px; color: #4f525a">HOTEL</span></div><div style="float: right; margin-right:8px; margin-top:3px;"><span>2088 reviews</span> <span style="padding: 4px; background-color: #7ccf50; color: white; border-radius: 2px; margin-left: 5px;">4.4/5</span></div></li><li><a href="https://www.goibibo.com/hotels/snow-valley-resorts-hotel-in-shimla-1953288179585905793/" onclick="event.stopPropagation();" target="_blank"><p style="font-size: 18px; font-weight: bolder; color: #141823;font-family: 'Quicksand', sans-serif;">Snow Valley Resorts</p></a></li><li style="color: #2276e3;"><p>Main Town, Shimla</p></li></ul><ul class="hotel-content-container-bottom-hinged-list"><li><i class="icon-ranking" style="font-size: 15px; margin-right: 3px; color: #fdba00"></i> <span class="htl-tile-top-tag-text" style="color: #2276e3; cursor: pointer">94% Guests recommend this hotel</span></li><li class="hotel-content-container-li-loc-usp" style=""><i class="icon-persuation-generic" style="font-size: 15px; margin-right: 3px;"></i> <span class="htl-tile-loc-pin-text"></span></li><li class="htl-tile-amenities-list" style=""><div  ...
# <div class="width100 fl htlListSeo hotel-tile-srp-container hotel-tile-srp-container-template new-htl-design-tile-main-block" id="htl-8689972586923762049" onclick="window.open('https://www.goibibo.com/hotels/shingar-hotel-in-shimla-8689972586923762049/');event.stopPropagation();"><div class="hotel-tile-srp-container-img-container"><div class="htl-tile-free-bkfst-overlay"><div class="text-label">Free breakfast</div><div class="label-decor"></div></div><div class="hotel-tile-srp-container-title-image"><img alt="Hotel Shingar - Main Town, Shimla" class="lazy" id="htl-tile-main-image-8689972586923762049" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" ori="https://gos3.ibcdn.com/hotel-shingar-shimla-night-view-58546963244g.jpg" pagespeed_url_hash="3446296193" src="https://gos3.ibcdn.com/hotel-shingar-shimla-night-view-58546963244g.jpg"/></div><ul class="hotel-tile-srp-container-image-gallery"><li><img alt="Hotel Images" class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/t_g3_ing_v9/hotel-shingar-shimla-hotel-shingar-shimla-reception-111976924538-orijgp.jpg" htl="8689972586923762049" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1704746537" src="https://cdn1.goibibo.com/t_r_v3/hotel-shingar-shimla-hotel-shingar-shimla-reception-111976924538-orijgp.jpg"/></li><li><img alt="Hotel Images" class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/t_g3_ing_v9/hotel-shingar-shimla-hotel-shingar-shimla-facade-111976753278-orijgp.jpg" htl="8689972586923762049" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="4034740093" src="https://cdn1.goibibo.com/t_r_v3/hotel-shingar-shimla-hotel-shingar-shimla-facade-111976753278-orijgp.jpg"/></li><li><img alt="Hotel Images" class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/t_g3_ing_v9/hotel-shingar-shimla-hotel-shingar-room_jpg-shimla-111976624565-orijgp.jpg" htl="8689972586923762049" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="3577225384" src="https://cdn1.goibibo.com/t_r_v3/hotel-shingar-shimla-hotel-shingar-room_jpg-shimla-111976624565-orijgp.jpg"/></li><li><img alt="Hotel Images" class="lazy htl-tile-gallery-image" fsi="https://gos3.ibcdn.com/hotel-shingar-shimla-bathroom-58546977789fs.jpg" htl="8689972586923762049" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="4224498317" src="https://gos3.ibcdn.com/hotel-shingar-shimla-bathroom-58546977789r.jpg"/></li><li><div style="cursor:pointer !important;">VIEW ALL</div><img alt="Hotel Images" class="lazy htl-tile-gallery-image" fsi="https://gos3.ibcdn.com/hotel-shingar-shimla-night-view-58546963244fs.jpg" htl="8689972586923762049" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="2390828028" src="https://gos3.ibcdn.com/hotel-shingar-shimla-night-view-58546963244r.jpg"/></li></ul></div><div class="hotel-tile-srp-container-content-container"><ul class="hotel-content-container-top-hinged-list"><li><div style="display: inline-block;"><i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <span style="padding: 2px; border: 1px solid #e5edf6; border-radius: 2px; margin-left: 5px; color: #4f525a">HOTEL</span></div><div style="float: right; margin-right:8px; margin-top:3px;"><span>1009 reviews</span> <span style="padding: 4px; background-color: #7ccf50; color: white; border-radius: 2px; margin-left: 5px;">4.1/5</span></div></li><li><a href="https://www.goibibo.com/hotels/shingar-hotel-in-shimla-8689972586923762049/" onclick="event.stopPropagation();" target="_blank"><p style="font-size: 18px; font-weight: bolder; color: #141823;font-family: 'Quicksand', sans-serif;">Hotel Shingar</p></a></li><li style="color: #2276e3;"><p>Main Town, Shimla</p></li></ul><ul class="hotel-c ...
# <div class="width100 fl htlListSeo hotel-tile-srp-container hotel-tile-srp-container-template new-htl-design-tile-main-block" id="htl-8833337098196373625" onclick="window.open('https://www.goibibo.com/hotels/marina-shimla-first-designer-boutique-hotel-in-shimla-8833337098196373625/');event.stopPropagation();"><div class="hotel-tile-srp-container-img-container"><div class="htl-tile-free-bkfst-overlay"><div class="text-label">Free breakfast</div><div class="label-decor"></div></div><div class="hotel-tile-srp-container-title-image"><img alt="Marina- Shimla First Designer Boutique Hotel - Mall Road Area, Shimla" class="lazy" id="htl-tile-main-image-8833337098196373625" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" ori="https://cdn1.goibibo.com/t_g_ing_v8/marina-shimla-first-designer-boutique-hotel-shimla-exterior-128415489726-orijgp.jpg" pagespeed_url_hash="1043802734" src="https://cdn1.goibibo.com/t_g_ing_v8/marina-shimla-first-designer-boutique-hotel-shimla-exterior-128415489726-orijgp.jpg"/></div><ul class="hotel-tile-srp-container-image-gallery"><li><img alt="Hotel Images" class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/t_g3_ing_v9/marina-shimla-first-designer-boutique-hotel-shimla-parking-area-100284835405-orijgp.jpg" htl="8833337098196373625" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="960544996" src="https://cdn1.goibibo.com/t_r_v3/marina-shimla-first-designer-boutique-hotel-shimla-parking-area-100284835405-orijgp.jpg"/></li><li><img alt="Hotel Images" class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/t_g3_ing_v9/marina-shimla-first-designer-boutique-hotel-shimla-hotel-marina-executive-room_jpg-shimla-111895677669-orijgp.jpg" htl="8833337098196373625" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1150143647" src="https://cdn1.goibibo.com/t_r_v3/marina-shimla-first-designer-boutique-hotel-shimla-hotel-marina-executive-room_jpg-shimla-111895677669-orijgp.jpg"/></li><li><div style="cursor:pointer !important;">VIEW ALL</div><img alt="Hotel Images" class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/t_g3_ing_v9/marina-shimla-first-designer-boutique-hotel-shimla-exterior-128415489726-orijgp.jpg" htl="8833337098196373625" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="3705740677" src="https://cdn1.goibibo.com/t_r_v3/marina-shimla-first-designer-boutique-hotel-shimla-exterior-128415489726-orijgp.jpg"/></li></ul></div><div class="hotel-tile-srp-container-content-container"><ul class="hotel-content-container-top-hinged-list"><li><div style="display: inline-block;"><i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <span style="padding: 2px; border: 1px solid #e5edf6; border-radius: 2px; margin-left: 5px; color: #4f525a">HOTEL</span></div><div style="float: right; margin-right:8px; margin-top:3px;"><span>842 reviews</span> <span style="padding: 4px; background-color: #7ccf50; color: white; border-radius: 2px; margin-left: 5px;">4.5/5</span></div></li><li><a href="https://www.goibibo.com/hotels/marina-shimla-first-designer-boutique-hotel-in-shimla-8833337098196373625/" onclick="event.stopPropagation();" target="_blank"><p style="font-size: 18px; font-weight: bolder; color: #141823;font-family: 'Quicksand', sans-serif;">Marina- Shimla First Designer Boutique Hotel</p></a></li><li style="color: #2276e3;"><p>Mall Road Area, Shimla</p></li></ul><ul class="hotel-content-container-bottom-hinged-list"><li><i class="icon-ranking" style="font-size: 15px; margin-right: 3px; color: #fdba00"></i> <span class="htl-tile-top-tag-text" style="color: #2276e3; cursor: pointer">95% Gue ...

# %%
# extract the hotel name and price per room
for card in cards_data:

    # get the hotel name
    hotel_name = card.find('p')

    # get the room price
    room_price = card.find('li', attrs={'class': 'htl-tile-discount-prc'})
    print(hotel_name.text, room_price.text)
# Out:
# (u'The Rock Castle', u'2275')
# (u'Hotel Combermere', u'6560')
# (u'Hotel Dalziel', u'1620')
# (u'Hotel Willow Banks', u'6396')
# (u'landmark shimla - With Elevator Access To Mall Road', u'3120')
# (u'Summit Thistle Villa Resort & Spa', u'3480')
# (u'Amritara The Zion Hotel', u'4900')
# (u'Snow Valley Resorts', u'3600')
# (u'Hotel Shingar', u'3040')
# (u'Marina- Shimla First Designer Boutique Hotel', u'6480')

# %%
# create a list to store the data
scraped_data = []

for card in cards_data:

    # initialize the dictionary
    card_details = {}

    # get the hotel name
    hotel_name = card.find('p')

    # get the room price
    room_price = card.find('li', attrs={'class': 'htl-tile-discount-prc'})

    # add data to the dictionary
    card_details['hotel_name'] = hotel_name.text
    card_details['room_price'] = room_price.text

    # append the scraped data to the list
    scraped_data.append(card_details)
    
# create a data frame from the list of dictionaries
dataFrame = pd.DataFrame.from_dict(scraped_data)

# save the scraped data as CSV file
dataFrame.to_csv('hotels_data.csv', index=False)
